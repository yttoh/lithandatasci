# %% [markdown]
# ### Activity 1: Data Loading and Exploration
#
# Initializing the analysis by loading and exploring the dataset, ensuring data integrity and format consistency
# for accurate downstream analysis.
#
# 1. Load the COVID-19 dataset using pandas from the provided dataset.
# 2. Display the first 5 and last 5 rows of the DataFrame.
# 3. Check for missing values in the dataset and decide on a strategy to handle them.
# 4. Remove the columns with more than 90% of missing values.
# 5. Convert the 'date' column to the datetime data type.

# %%
import pandas as pd

# %%
#load dataset into a dataframe
covid = pd.read_csv('covid.csv', index_col=0)

# %%
covid.shape
# Out:
# (358838, 66)

# %%
#display first 5 rows of datframe
covid.head(5)
# Out:
#          continent     location        date  total_cases  new_cases  \
# iso_code
# AFG           Asia  Afghanistan  2020-01-03          NaN        0.0
# AFG           Asia  Afghanistan  2020-01-04          NaN        0.0
# AFG           Asia  Afghanistan  2020-01-05          NaN        0.0
# AFG           Asia  Afghanistan  2020-01-06          NaN        0.0
# AFG           Asia  Afghanistan  2020-01-07          NaN        0.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# AFG                      NaN           NaN         0.0                  NaN
# AFG                      NaN           NaN         0.0                  NaN
# AFG                      NaN           NaN         0.0                  NaN
# AFG                      NaN           NaN         0.0                  NaN
# AFG                      NaN           NaN         0.0                  NaN
#
#           total_cases_per_million  ...  male_smokers  handwashing_facilities  \
# iso_code                           ...
# AFG                           NaN  ...           NaN                  37.746
# AFG                           NaN  ...           NaN                  37.746
# AFG                           NaN  ...           NaN                  37.746
# AFG                           NaN  ...           NaN                  37.746
# AFG                           NaN  ...           NaN                  37.746
#
#           hospital_beds_per_thousand  life_expectancy  \
# iso_code
# AFG                              0.5            64.83
# AFG                              0.5            64.83
# AFG                              0.5            64.83
# AFG                              0.5            64.83
# AFG                              0.5            64.83
#
#           human_development_index  population  \
# iso_code
# AFG                         0.511  41128772.0
# AFG                         0.511  41128772.0
# AFG                         0.511  41128772.0
# AFG                         0.511  41128772.0
# AFG                         0.511  41128772.0
#
#           excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# iso_code
# AFG                                        NaN                          NaN
# AFG                                        NaN                          NaN
# AFG                                        NaN                          NaN
# AFG                                        NaN                          NaN
# AFG                                        NaN                          NaN
#
#           excess_mortality  excess_mortality_cumulative_per_million
# iso_code
# AFG                    NaN                                      NaN
# AFG                    NaN                                      NaN
# AFG                    NaN                                      NaN
# AFG                    NaN                                      NaN
# AFG                    NaN                                      NaN
#
# [5 rows x 66 columns]

# %%
#display last 5 rows of datframe
covid.tail(5)
# Out:
#          continent  location        date  total_cases  new_cases  \
# iso_code
# ZWE         Africa  Zimbabwe  2023-11-18     265890.0        0.0
# ZWE         Africa  Zimbabwe  2023-11-19     265890.0        0.0
# ZWE         Africa  Zimbabwe  2023-11-20     265890.0        0.0
# ZWE         Africa  Zimbabwe  2023-11-21     265890.0        0.0
# ZWE         Africa  Zimbabwe  2023-11-22     265890.0        0.0
#
#           new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# iso_code
# ZWE                      0.0        5725.0         0.0                  0.0
# ZWE                      0.0        5725.0         0.0                  0.0
# ZWE                      0.0        5725.0         0.0                  0.0
# ZWE                      0.0        5725.0         0.0                  0.0
# ZWE                      0.0        5725.0         0.0                  0.0
#
#           total_cases_per_million  ...  male_smokers  handwashing_facilities  \
# iso_code                           ...
# ZWE                     16291.741  ...          30.7                  36.791
# ZWE                     16291.741  ...          30.7                  36.791
# ZWE                     16291.741  ...          30.7                  36.791
# ZWE                     16291.741  ...          30.7                  36.791
# ZWE                     16291.741  ...          30.7                  36.791
#
#           hospital_beds_per_thousand  life_expectancy  \
# iso_code
# ZWE                              1.7            61.49
# ZWE                              1.7            61.49
# ZWE                              1.7            61.49
# ZWE                              1.7            61.49
# ZWE                              1.7            61.49
#
#           human_development_index  population  \
# iso_code
# ZWE                         0.571  16320539.0
# ZWE                         0.571  16320539.0
# ZWE                         0.571  16320539.0
# ZWE                         0.571  16320539.0
# ZWE                         0.571  16320539.0
#
#           excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# iso_code
# ZWE                                        NaN                          NaN
# ZWE                                        NaN                          NaN
# ZWE                                        NaN                          NaN
# ZWE                                        NaN                          NaN
# ZWE                                        NaN                          NaN
#
#           excess_mortality  excess_mortality_cumulative_per_million
# iso_code
# ZWE                    NaN                                      NaN
# ZWE                    NaN                                      NaN
# ZWE                    NaN                                      NaN
# ZWE                    NaN                                      NaN
# ZWE                    NaN                                      NaN
#
# [5 rows x 66 columns]

# %%
covid.isnull().sum()
# Out:
# continent                                   17108
# location                                        0
# date                                            0
# total_cases                                 38210
# new_cases                                    9806
#                                             ...
# population                                      0
# excess_mortality_cumulative_absolute       346627
# excess_mortality_cumulative                346627
# excess_mortality                           346627
# excess_mortality_cumulative_per_million    346627
# Length: 66, dtype: int64

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 358838 entries, AFG to ZWE
# Data columns (total 66 columns):
#  #   Column                                      Non-Null Count   Dtype
# ---  ------                                      --------------   -----
#  0   continent                                   341730 non-null  object
#  1   location                                    358838 non-null  object
#  2   date                                        358838 non-null  object
#  3   total_cases                                 320628 non-null  float64
#  4   new_cases                                   349032 non-null  float64
#  5   new_cases_smoothed                          347773 non-null  float64
#  6   total_deaths                                299086 non-null  float64
#  7   new_deaths                                  349089 non-null  float64
#  8   new_deaths_smoothed                         347859 non-null  float64
#  9   total_cases_per_million                     320628 non-null  float64
#  10  new_cases_per_million                       349032 non-null  float64
#  11  new_cases_smoothed_per_million              347773 non-null  float64
#  12  total_deaths_per_million                    299086 non-null  float64
#  13  new_deaths_per_million                      349089 non-null  float64
#  14  new_deaths_smoothed_per_million             347859 non-null  float64
#  15  reproduction_rate                           184817 non-null  float64
#  16  icu_patients                                37853 non-null   float64
#  17  icu_patients_per_million                    37853 non-null   float64
#  18  hosp_patients                               39263 non-null   float64
#  19  hosp_patients_per_million                   39263 non-null   float64
#  20  weekly_icu_admissions                       10314 non-null   float64
#  21  weekly_icu_admissions_per_million           10314 non-null   float64
#  22  weekly_hosp_admissions                      23521 non-null   float64
#  23  weekly_hosp_admissions_per_million          23521 non-null   float64
#  24  total_tests                                 79387 non-null   float64
#  25  new_tests                                   75403 non-null   float64
#  26  total_tests_per_thousand                    79387 non-null   float64
#  27  new_tests_per_thousand                      75403 non-null   float64
#  28  new_tests_smoothed                          103965 non-null  float64
#  29  new_tests_smoothed_per_thousand             103965 non-null  float64
#  30  positive_rate                               95927 non-null   float64
#  31  tests_per_case                              94348 non-null   float64
#  32  tests_units                                 106788 non-null  object
#  33  total_vaccinations                          80162 non-null   float64
#  34  people_vaccinated                           76724 non-null   float64
#  35  people_fully_vaccinated                     73420 non-null   float64
#  36  total_boosters                              48358 non-null   float64
#  37  new_vaccinations                            66124 non-null   float64
#  38  new_vaccinations_smoothed                   184057 non-null  float64
#  39  total_vaccinations_per_hundred              80162 non-null   float64
#  40  people_vaccinated_per_hundred               76724 non-null   float64
#  41  people_fully_vaccinated_per_hundred         73420 non-null   float64
#  42  total_boosters_per_hundred                  48358 non-null   float64
#  43  new_vaccinations_smoothed_per_million       184057 non-null  float64
#  44  new_people_vaccinated_smoothed              183804 non-null  float64
#  45  new_people_vaccinated_smoothed_per_hundred  183804 non-null  float64
#  46  stringency_index                            197651 non-null  float64
#  47  population_density                          304672 non-null  float64
#  48  median_age                                  283301 non-null  float64
#  49  aged_65_older                               273432 non-null  float64
#  50  aged_70_older                               280461 non-null  float64
#  51  gdp_per_capita                              277692 non-null  float64
#  52  extreme_poverty                             179007 non-null  float64
#  53  cardiovasc_death_rate                       278348 non-null  float64
#  54  diabetes_prevalence                         292517 non-null  float64
#  55  female_smokers                              208840 non-null  float64
#  56  male_smokers                                206000 non-null  float64
#  57  handwashing_facilities                      136345 non-null  float64
#  58  hospital_beds_per_thousand                  245760 non-null  float64
#  59  life_expectancy                             330161 non-null  float64
#  60  human_development_index                     269789 non-null  float64
#  61  population                                  358838 non-null  float64
#  62  excess_mortality_cumulative_absolute        12211 non-null   float64
#  63  excess_mortality_cumulative                 12211 non-null   float64
#  64  excess_mortality                            12211 non-null   float64
#  65  excess_mortality_cumulative_per_million     12211 non-null   float64
# dtypes: float64(62), object(4)
# memory usage: 183.4+ MB

# %%
#Remove the columns with more than 90% of missing values.
missingThreshold = 0.9

covidFilter=covid.dropna(thresh=(1-missingThreshold)*len(covid),axis=1)

# %%
df = covidFilter[['continent', 'location', 'date', 'total_cases','new_cases', 'total_deaths', 'new_deaths','total_tests', 'new_tests', 'total_vaccinations', 'people_vaccinated', 'female_smokers', 'male_smokers', 'hospital_beds_per_thousand','new_deaths_per_million','new_cases_per_million','positive_rate']]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 358838 entries, AFG to ZWE
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   continent                   341730 non-null  object
#  1   location                    358838 non-null  object
#  2   date                        358838 non-null  object
#  3   total_cases                 320628 non-null  float64
#  4   new_cases                   349032 non-null  float64
#  5   total_deaths                299086 non-null  float64
#  6   new_deaths                  349089 non-null  float64
#  7   total_tests                 79387 non-null   float64
#  8   new_tests                   75403 non-null   float64
#  9   total_vaccinations          80162 non-null   float64
#  10  people_vaccinated           76724 non-null   float64
#  11  female_smokers              208840 non-null  float64
#  12  male_smokers                206000 non-null  float64
#  13  hospital_beds_per_thousand  245760 non-null  float64
#  14  new_deaths_per_million      349089 non-null  float64
#  15  new_cases_per_million       349032 non-null  float64
#  16  positive_rate               95927 non-null   float64
# dtypes: float64(14), object(3)
# memory usage: 49.3+ MB

# %%
#Convert the 'date' column to the datetime data type.
df['date']=pd.to_datetime(df['date'])
# Out:
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_22223/2335182614.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['date']=pd.to_datetime(df['date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 358838 entries, AFG to ZWE
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   continent                   341730 non-null  object
#  1   location                    358838 non-null  object
#  2   date                        358838 non-null  datetime64[ns]
#  3   total_cases                 320628 non-null  float64
#  4   new_cases                   349032 non-null  float64
#  5   total_deaths                299086 non-null  float64
#  6   new_deaths                  349089 non-null  float64
#  7   total_tests                 79387 non-null   float64
#  8   new_tests                   75403 non-null   float64
#  9   total_vaccinations          80162 non-null   float64
#  10  people_vaccinated           76724 non-null   float64
#  11  female_smokers              208840 non-null  float64
#  12  male_smokers                206000 non-null  float64
#  13  hospital_beds_per_thousand  245760 non-null  float64
#  14  new_deaths_per_million      349089 non-null  float64
#  15  new_cases_per_million       349032 non-null  float64
#  16  positive_rate               95927 non-null   float64
# dtypes: datetime64[ns](1), float64(14), object(2)
# memory usage: 49.3+ MB

# %% [markdown]
# ### Activity 2: Data Cleaning and Feature Engineering Enhancing data relevance and structure, enabling focused analysis on key COVID-19 indicators and demographic factors.
#
# 1. Impute missing values in the dataset columns
#
# 2. Remove duplicate rows from the DataFrame.
#
# 3. Create new features if needed (e.g., extract year and month from the 'date' column).
#
# 4. Explore unique countries in the dataset and count the total number of countries.

# %%
df.shape
# Out:
# (358838, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 358838 entries, AFG to ZWE
# Data columns (total 17 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   continent                   341730 non-null  object
#  1   location                    358838 non-null  object
#  2   date                        358838 non-null  datetime64[ns]
#  3   total_cases                 320628 non-null  float64
#  4   new_cases                   349032 non-null  float64
#  5   total_deaths                299086 non-null  float64
#  6   new_deaths                  349089 non-null  float64
#  7   total_tests                 79387 non-null   float64
#  8   new_tests                   75403 non-null   float64
#  9   total_vaccinations          80162 non-null   float64
#  10  people_vaccinated           76724 non-null   float64
#  11  female_smokers              208840 non-null  float64
#  12  male_smokers                206000 non-null  float64
#  13  hospital_beds_per_thousand  245760 non-null  float64
#  14  new_deaths_per_million      349089 non-null  float64
#  15  new_cases_per_million       349032 non-null  float64
#  16  positive_rate               95927 non-null   float64
# dtypes: datetime64[ns](1), float64(14), object(2)
# memory usage: 49.3+ MB

# %%
df.isnull().sum()
# Out:
# continent                      17108
# location                           0
# date                               0
# total_cases                    38210
# new_cases                       9806
# total_deaths                   59752
# new_deaths                      9749
# total_tests                   279451
# new_tests                     283435
# total_vaccinations            278676
# people_vaccinated             282114
# female_smokers                149998
# male_smokers                  152838
# hospital_beds_per_thousand    113078
# new_deaths_per_million          9749
# new_cases_per_million           9806
# positive_rate                 262911
# dtype: int64

# %%
numerical = df[['total_cases','new_cases', 'total_deaths', 'new_deaths','total_tests', 'new_tests', 'total_vaccinations', 'people_vaccinated', 'female_smokers', 'male_smokers', 'hospital_beds_per_thousand','new_deaths_per_million','new_cases_per_million','positive_rate']]

# %%
for col in numerical:
    df[col].fillna(df[col].median(), inplace=True)
# Out:
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_22223/2714759758.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col].fillna(df[col].median(), inplace=True)

# %%
df['continent'].fillna('Unknown', inplace=True)
# Out:
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_22223/2814043309.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['continent'].fillna('Unknown', inplace=True)

# %%
df.isnull().sum()
# Out:
# continent                     0
# location                      0
# date                          0
# total_cases                   0
# new_cases                     0
# total_deaths                  0
# new_deaths                    0
# total_tests                   0
# new_tests                     0
# total_vaccinations            0
# people_vaccinated             0
# female_smokers                0
# male_smokers                  0
# hospital_beds_per_thousand    0
# new_deaths_per_million        0
# new_cases_per_million         0
# positive_rate                 0
# dtype: int64

# %%
#remove duplicate rows in dataframe

df.drop_duplicates(inplace=True)
# Out:
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_22223/4085955388.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
#Extract month and year from date column

df['month']=df['date'].dt.month
df['year']=df['date'].dt.year
# Out:
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_22223/544080516.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['month']=df['date'].dt.month
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_22223/544080516.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['year']=df['date'].dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 358838 entries, AFG to ZWE
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   continent                   358838 non-null  object
#  1   location                    358838 non-null  object
#  2   date                        358838 non-null  datetime64[ns]
#  3   total_cases                 358838 non-null  float64
#  4   new_cases                   358838 non-null  float64
#  5   total_deaths                358838 non-null  float64
#  6   new_deaths                  358838 non-null  float64
#  7   total_tests                 358838 non-null  float64
#  8   new_tests                   358838 non-null  float64
#  9   total_vaccinations          358838 non-null  float64
#  10  people_vaccinated           358838 non-null  float64
#  11  female_smokers              358838 non-null  float64
#  12  male_smokers                358838 non-null  float64
#  13  hospital_beds_per_thousand  358838 non-null  float64
#  14  new_deaths_per_million      358838 non-null  float64
#  15  new_cases_per_million       358838 non-null  float64
#  16  positive_rate               358838 non-null  float64
#  17  month                       358838 non-null  int32
#  18  year                        358838 non-null  int32
# dtypes: datetime64[ns](1), float64(14), int32(2), object(2)
# memory usage: 52.0+ MB

# %%
df['location'].unique()
# Out:
# array(['Afghanistan', 'Africa', 'Albania', 'Algeria', 'American Samoa',
#        'Andorra', 'Angola', 'Anguilla', 'Antigua and Barbuda',
#        'Argentina', 'Armenia', 'Aruba', 'Asia', 'Australia', 'Austria',
#        'Azerbaijan', 'Bahamas', 'Bahrain', 'Bangladesh', 'Barbados',
#        'Belarus', 'Belgium', 'Belize', 'Benin', 'Bermuda', 'Bhutan',
#        'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'England', 'Equatorial Guinea', 'Eritrea',
#        'Estonia', 'Eswatini', 'Ethiopia', 'Europe', 'European Union',
#        'Faeroe Islands', 'Falkland Islands', 'Fiji', 'Finland', 'France',
#        'French Guiana', 'French Polynesia', 'Gabon', 'Gambia', 'Georgia',
#        'Germany', 'Ghana', 'Gibraltar', 'Greece', 'Greenland', 'Grenada',
#        'Guadeloupe', 'Guam', 'Guatemala', 'Guernsey', 'Guinea',
#        'Guinea-Bissau', 'Guyana', 'Haiti', 'High income', 'Honduras',
#        'Hong Kong', 'Hungary', 'Iceland', 'India', 'Indonesia', 'Iran',
#        'Iraq', 'Ireland', 'Isle of Man', 'Israel', 'Italy', 'Jamaica',
#        'Japan', 'Jersey', 'Jordan', 'Kazakhstan', 'Kenya', 'Kiribati',
#        'Kosovo', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Liechtenstein', 'Lithuania',
#        'Low income', 'Lower middle income', 'Luxembourg', 'Macao',
#        'Madagascar', 'Malawi', 'Malaysia', 'Maldives', 'Mali', 'Malta',
#        'Marshall Islands', 'Martinique', 'Mauritania', 'Mauritius',
#        'Mayotte', 'Mexico', 'Micronesia (country)', 'Moldova', 'Monaco',
#        'Mongolia', 'Montenegro', 'Montserrat', 'Morocco', 'Mozambique',
#        'Myanmar', 'Namibia', 'Nauru', 'Nepal', 'Netherlands',
#        'New Caledonia', 'New Zealand', 'Nicaragua', 'Niger', 'Nigeria',
#        'Niue', 'North America', 'North Korea', 'North Macedonia',
#        'Northern Cyprus', 'Northern Ireland', 'Northern Mariana Islands',
#        'Norway', 'Oceania', 'Oman', 'Pakistan', 'Palau', 'Palestine',
#        'Panama', 'Papua New Guinea', 'Paraguay', 'Peru', 'Philippines',
#        'Pitcairn', 'Poland', 'Portugal', 'Puerto Rico', 'Qatar',
#        'Reunion', 'Romania', 'Russia', 'Rwanda', 'Saint Barthelemy',
#        'Saint Helena', 'Saint Kitts and Nevis', 'Saint Lucia',
#        'Saint Martin (French part)', 'Saint Pierre and Miquelon',
#        'Saint Vincent and the Grenadines', 'Samoa', 'San Marino',
#        'Sao Tome and Principe', 'Saudi Arabia', 'Scotland', 'Senegal',
#        'Serbia', 'Seychelles', 'Sierra Leone', 'Singapore',
#        'Sint Maarten (Dutch part)', 'Slovakia', 'Slovenia',
#        'Solomon Islands', 'Somalia', 'South Africa', 'South America',
#        'South Korea', 'South Sudan', 'Spain', 'Sri Lanka', 'Sudan',
#        'Suriname', 'Sweden', 'Switzerland', 'Syria', 'Taiwan',
#        'Tajikistan', 'Tanzania', 'Thailand', 'Timor', 'Togo', 'Tokelau',
#        'Tonga', 'Trinidad and Tobago', 'Tunisia', 'Turkey',
#        'Turkmenistan', 'Turks and Caicos Islands', 'Tuvalu', 'Uganda',
#        'Ukraine', 'United Arab Emirates', 'United Kingdom',
#        'United States', 'United States Virgin Islands',
#        'Upper middle income', 'Uruguay', 'Uzbekistan', 'Vanuatu',
#        'Vatican', 'Venezuela', 'Vietnam', 'Wales', 'Wallis and Futuna',
#        'Western Sahara', 'World', 'Yemen', 'Zambia', 'Zimbabwe'],
#       dtype=object)

# %%
unique_countries= df['location'].unique()

# %%
unique_countries.shape
# Out:
# (255,)

# %%
len(unique_countries)
# Out:
# 255

# %%
df['location'].value_counts()
#total number of countries is 255.
# Out:
# location
# High income            1428
# Upper middle income    1428
# North America          1428
# India                  1428
# World                  1428
#                        ...
# Scotland               1305
# Wales                  1198
# Macao                   795
# Northern Cyprus         691
# Western Sahara            1
# Name: count, Length: 255, dtype: int64

# %% [markdown]
# ### Activity 3: Worldwide COVID-19 Overview Providing a global and temporal perspective on COVID-19, identifying patterns and correlations crucial for strategic decision-making.
#
# 1. Visualize the total COVID-19 cases and total deaths by continent using bar plots.
#
# 2. Explore the monthly trend of new COVID-19 cases using a line plot.
#
# 3. Investigate the correlation between total cases and total deaths using a heatmap.
#
# 4. Analyze how total cases have evolved over time for a specific location (e.g., India).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# #### 1.Visualize the total COVID-19 cases and total deaths by continent using bar plots.

# %%
selected = df.drop(columns=['date'])

#filter out rows with unknown continent

filtered_df = selected[selected['continent'] != 'Unknown']

#group by continent and sum the total cases and total deaths

grouped_df = filtered_df.groupby('continent').sum()[['total_cases','total_deaths']]

#plot the bar chart 

grouped_df.plot(kind='bar', figsize=(15,7))
plt.title('Total COVID-19 Cases and Total Deaths by Continent')
plt.xlabel('Continent')
plt.ylabel('Number of Cases/Deaths')
plt.show()

# %% [markdown]
# #### 2. Explore the monthly trend of new COVID-19 cases using a line plot.

# %%
plt.figure(figsize=(12, 6))
sns.lineplot(x='date', y='new_cases', data=df)
plt.title('Monthly Trend of New COVID-19 Cases')
plt.xlabel('Date')
plt.ylabel('New Cases')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### 3. Investigate the correlation between total cases and total deaths using a heatmap.

# %%
#find correlation between total cases and total deaths using a heatmap.

sns.heatmap(df[['total_cases', 'total_deaths']].corr(), annot=True, cmap='coolwarm')
plt.title('Correlation between Total Cases and Total Deaths')
plt.show()

# %% [markdown]
# #### 4. Analyze how total cases have evolved over time for a specific location (e.g., India).

# %%
# analyse how total cases have evolved over time in India

#filter out data for India
location_data = df[df['location'] == 'India']

#plot total cases over time for India
plt.figure(figsize=(12, 6))
sns.lineplot(x='date', y='total_cases', data=location_data)
plt.title('Total COVID-19 Cases in India Over Time')
plt.xlabel('Date')
plt.ylabel('Total Cases')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ### Activity 4: Regional Analysis Unveiling regional nuances in COVID-19 dynamics and identifying patterns in case distribution and fatality across time and continents.
# 1. Create a grouped bar chart to visualize new cases by continent and month.
#
# 2. Visualize the distribution of total COVID-19 cases by year using a box plot.
#
# 3. Compare total deaths across different continents using a bar plot.
#
# 4. Analyze the total cases on a month-by-month basis using a bar plot.

# %% [markdown]
# #### 1. Create a grouped bar chart to visualize new cases by continent and month.

# %%
#group bar chart by continent and month
plt.figure(figsize=(12, 8))
sns.barplot(x='month', y='new_cases', hue='continent', data=filtered_df, errorbar=None)
plt.title('New COVID-19 Cases by Continent and Month')
plt.xlabel('Month')
plt.ylabel('New Cases')
plt.legend(title='Continent')
plt.show()

# %% [markdown]
# #### 2. Visualize the distribution of total COVID-19 cases by year using a box plot.

# %%
#plot box plot for total covid cases by year
plt.figure(figsize=(12, 6))
sns.boxplot(x='year', y='total_cases', data=df)
plt.title('Total COVID-19 Cases by Year')
plt.xlabel('Year')
plt.ylabel('Total Cases')
# Out:
# Text(0, 0.5, 'Total Cases')

# %% [markdown]
# #### 3. Compare total deaths across different continents using a bar plot.

# %%
#plot bar graph of total deaths grouped by continents
plt.figure(figsize=(12, 6))
sns.barplot(x='continent', y='total_deaths', data=filtered_df, errorbar=None)
plt.title('Total COVID-19 Deaths by Continent')
plt.xlabel('Continent')
plt.ylabel('Total Deaths')
# Out:
# Text(0, 0.5, 'Total Deaths')

# %% [markdown]
# #### 4. Analyze the total cases on a month-by-month basis using a bar plot.

# %%
totalcasebymonth = df.groupby('month')['total_cases'].sum().reset_index()

# %%
#plot bar plot by month of total cases
plt.figure(figsize=(12, 6))
sns.barplot(x='month', y='total_cases', data=totalcasebymonth, errorbar=None)
plt.title('Total COVID-19 Cases by Month')
plt.xlabel('Month')
plt.ylabel('Total Cases')
plt.show()

# %% [markdown]
# ### Activity 5: Time Series Analysis Capturing the daily dynamics of COVID-19, assessing the impact of vaccination, and monitoring testing metrics for a comprehensive global overview.
# 1. Explore the daily trend of new cases and new deaths globally using line plots.
#
# 2. Calculate and visualize the daily average new cases and deaths globally.
#
# 3. Explore the trend of vaccination coverage over time globally.
#
# 4. Analyze the total tests and positive rate over time globally.

# %% [markdown]
# #### 1. Explore the daily trend of new cases and new deaths globally using line plots.

# %%
filter_df = df[df['continent'] != 'Unknown']

# %%
#plot line graph of daily new cases 

plt.figure(figsize=(12,8))
sns.lineplot(x='date', y='new_cases', data=filter_df, hue='continent', errorbar=None)
plt.title('Daily Trend of New Cases')
plt.xlabel('Date')
plt.ylabel('New Cases')
plt.show()


#plot line graph of daily new deaths 

plt.figure(figsize=(12,8))
sns.lineplot(x='date', y='new_deaths', data=filter_df, hue='continent', errorbar=None)
plt.title('Daily Trend of New Deaths')
plt.xlabel('Date')
plt.ylabel('New Cases')
plt.show()

# %% [markdown]
# #### 2. Calculate and visualize the daily average new cases and deaths globally.

# %%
#get average 
dailyaverage = filter_df.groupby('date').agg({'new_cases':'mean', 'new_deaths':'mean'}).reset_index()

# %%
#create line plot of average daily new cases

plt.figure(figsize=(12,8))
sns.lineplot(x='date', y='new_cases', data=dailyaverage, errorbar=None)
plt.title('Daily Trend of New Cases')
plt.xlabel('Date')
plt.ylabel('New Cases')
plt.show()


#plot line graph of daily average new deaths 

plt.figure(figsize=(12,8))
sns.lineplot(x='date', y='new_deaths', data=dailyaverage, errorbar=None)
plt.title('Daily Trend of New Deaths')
plt.xlabel('Date')
plt.ylabel('New Cases')
plt.show()

# %% [markdown]
# #### 3. Explore the trend of vaccination coverage over time globally.

# %%
#plot line graph of vaccination trend over time
plt.figure(figsize=(12, 6))
sns.lineplot(x='date', y='people_vaccinated', data=df, errorbar=None)
plt.title('Vaccination Trend Over Time')
plt.xlabel('Date')
plt.ylabel('People Vaccinated')
# Out:
# Text(0, 0.5, 'People Vaccinated')

# %% [markdown]
# #### 4. Analyze the total tests and positive rate over time globally.

# %%
#figure and axis with dual y-axis

fig, ax1 = plt.subplots(figsize=(12,6))

#total tests
sns.lineplot(x='date', y='total_tests', data=df, color='blue', ax=ax1, errorbar=None)
ax1.set_xlabel('Date')
ax1.set_ylabel('Total Tests')

#positive rate
ax2= ax1.twinx()
sns.lineplot(x='date', y='positive_rate', data=df, color='red', ax=ax2, errorbar=None)
ax2.set_xlabel('Date')
ax2.set_ylabel('Positive Rate')
# Out:
# Text(0, 0.5, 'Positive Rate')

# %% [markdown]
# ### Activity 6: In-Depth Country Analysis
# Conducting an in-depth examination of specific countries, understanding the correlation between cases and
# deaths globally, and exploring continental variations in case distribution.
# 1. Visualize the total COVID-19 cases and deaths over time for a specific country.
# 2. Get user input for the country and metric (total_cases or total_deaths) and plot a line chart for the user
# selected values.
# 3. Analyze the distribution of total cases across different continents using a box plot.
# 4. Visualize the Year wise monthly trend of new COVID-19 cases for user selected country.

# %% [markdown]
# #### 1.Visualize the total COVID-19 cases and deaths over time for a specific country.

# %%
countryData = df[df['location']=='India']

plt.figure(figsize=(14,8))
sns.lineplot(x='date', y='total_cases', data=countryData)
sns.lineplot(x='date', y='total_deaths', data=countryData)
plt.title('Total Covid-19 Cases and Deaths Over Time for India')
plt.xlabel('Date')
plt.ylabel('Count')
plt.legend(['Cases','Deaths'])
plt.show()

# %% [markdown]
# #### 2. Get user input for the country and metric (total_cases or total_deaths) and plot a line chart for the user selected values.

# %%
#get user country
selectedCountry=input("Enter the country:")

#get which metric
selectedDataCase = input("Enter the metric (total_cases or total_deaths)")

#get data based on country
countryData= df[df['location']==selectedCountry]

plt.figure(figsize=(14,8))
sns.lineplot(x='date', y=selectedDataCase, data=countryData, errorbar=None)
plt.title('Total Covid-19 Cases and Deaths for '+ selectedCountry)
plt.xlabel('Date')
plt.ylabel('Count')
plt.show()
# Out:
# Enter the country:India
# Enter the metric (total_cases or total_deaths)total_cases

# %% [markdown]
# #### 3. Analyze the distribution of total cases across different continents using a box plot.

# %%
plt.figure(figsize=(14,8))
sns.boxplot(x='continent', y='total_cases', data=filter_df)
plt.title('Distribution of Total Cases Across Different Continents')
plt.xlabel('Continent')
plt.ylabel('Total Cases')
plt.show()

# %% [markdown]
# #### 4.Visualize the Year wise monthly trend of new COVID-19 cases for user selected country.

# %%
selectedCountry = input("Enter the country: ")

countryData=filter_df[filter_df['location'] == selectedCountry]

countryData['month']=pd.to_datetime(countryData['date']).dt.month
countryData['year']=pd.to_datetime(countryData['date']).dt.year

#group by month and year
monthlyData= countryData.groupby(['year', 'month'])['new_cases'].sum().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(x='month', y='new_cases', hue='year', data=monthlyData)
plt.title('Monthly Trend of New COVID-19 Cases for' + selectedCountry)
plt.xlabel('Month')
plt.ylabel('New Cases')
plt.legend(title='Year')
plt.show()
# Out:
# Enter the country: India
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_22223/272302644.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   countryData['month']=pd.to_datetime(countryData['date']).dt.month
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_22223/272302644.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   countryData['year']=pd.to_datetime(countryData['date']).dt.year

# %% [markdown]
# ### Activity 7: Additional Insights
# Extracting additional insights, examining the influence of external factors, and evaluating regional disparities
# for a holistic understanding of the COVID-19 landscape.
# 1. Visualize the fatality rate (total deaths / total cases) over time globally.
# 2. Explore positivity rate (total_cases/ total tests) verses total tests conducted to analyse testing effectiveness
# use x axis as logarithmic scale for better visualization.
# 3. Analyze fatality rate and its relationship with smoking (Use male_smokers and female_smokers columns)
# 4. Create a heatmap to analyze the relationship between hospital beds per thousand and fatality rate.

# %% [markdown]
# #### 1.Visualize the fatality rate (total deaths / total cases) over time globally.

# %%
#calculate global fatality rate
df['global_fatality_rate']= df['total_deaths'] / df['total_cases']
# Out:
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_22223/867130426.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['global_fatality_rate']= df['total_deaths'] / df['total_cases']

# %%
#plot graph of fatality rate over time
plt.figure(figsize=(12, 6))
sns.lineplot(x='date', y='global_fatality_rate', data=df, errorbar=None)
plt.title('Global Fatality Rate Over Time')
plt.xlabel('Date')
plt.ylabel('Global Fatality Rate')
# Out:
# Text(0, 0.5, 'Global Fatality Rate')

# %% [markdown]
# #### 2.Explore positivity rate (total_cases/ total tests) verses total tests conducted to analyse testing effectiveness use x axis as logarithmic scale for better visualization.

# %%
#calculate positive rate
df['positivity_rate'] = df['total_cases'] / df['total_tests']
# Out:
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_22223/1639392526.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['positivity_rate'] = df['total_cases'] / df['total_tests']

# %%
#plot scatter plot to show effectiveness of total tests versus positive rate

sns.scatterplot(x='total_tests', y='positivity_rate', data=df)
plt.title('Positivity Rate vs Total Tests')
plt.xlabel('Total Tests')
plt.ylabel('Positivity Rate')
plt.show()

# %% [markdown]
# #### 3. Analyze fatality rate and its relationship with smoking (Use male_smokers and female_smokers columns)

# %%
df['total_smokers'] = df['female_smokers']+ df['male_smokers']
# Out:
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_22223/1730727963.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['total_smokers'] = df['female_smokers']+ df['male_smokers']

# %%
filter_df = df[df['continent'] != 'Unknown']

# %%
#grouop by country and calculate total deaths and total smokers 
CountryData= filter_df.groupby('location').agg({'total_deaths':'sum','total_smokers':'sum'}).reset_index()

# %%
#sort by tottal smokers in descending order
CountryData=CountryData.sort_values(by='total_smokers', ascending=False).head(10)

# %%
#create diverging bar chart using seaborn to show total death and total smokers for the top countries
 

plt.figure(figsize=(12, 6))
sns.barplot(x='total_smokers', y='location', data=CountryData, color='blue')
sns.barplot(x='total_deaths', y='location', data=CountryData, color='red')

plt.title('Fatality Rate and Total Smokers')
plt.xlabel('Total Smokers')
plt.ylabel('Country')
plt.legend(['Total Smokers'],['Total Deaths'])
plt.xscale('log')
plt.show()
# Out:
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_22223/563374345.py:11: UserWarning: Legend does not support handles for str instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/stable/tutorials/intermediate/legend_guide.html#controlling-the-legend-entries
#   plt.legend(['Total Smokers'],['Total Deaths'])

# %% [markdown]
# #### 4. Create a heatmap to analyze the relationship between hospital beds per thousand and fatality rate.

# %%
#find correlation between hospital beds and fatality rate using a heatmap.

heatmapdata=df[['hospital_beds_per_thousand','global_fatality_rate']].dropna()

sns.histplot(x='hospital_beds_per_thousand', y='global_fatality_rate', data=heatmapdata, bins =(50,50), cmap='coolwarm',cbar=True)
plt.title('Hospital Beds per Thousand vs Fatality Rate')
plt.xlabel('Hospital Beds per Thousand')
plt.ylabel('Fatality Rate')
plt.show()

# %%
#find correlation between hospital beds and fatality rate using a heatmap.

sns.heatmap(heatmapdata.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation between Hospital Beds and Total Deaths')
plt.show()
