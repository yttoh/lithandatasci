# %% [markdown]
# ## Activity 1- Data Loading and Exploration:

# %% [markdown]
# • Task 1: Load the OKCupid dataset.
# • Task 2: Explore the dataset to understand its structure.
# • Task 3: Visualize and describe the distribution of key variables like age, height, and
# income.
# • Task 4: Explore categorical variables such as gender, body type, diet, drinks, drugs,
# education, etc.
# • Task 5: Summarize initial observations from data exploration.

# %%
import numpy as np
import pandas as pd

# %%
#Task 1: Load the OKCupid dataset.

df= pd.read_csv('profiles.csv')

df
# Out:
#        age     status sex orientation       body_type               diet  \
# 0       22     single   m    straight  a little extra  strictly anything
# 1       35     single   m    straight         average       mostly other
# 2       38  available   m    straight            thin           anything
# 3       23     single   m    straight            thin         vegetarian
# 4       29     single   m    straight        athletic                NaN
# ...    ...        ...  ..         ...             ...                ...
# 59941   59     single   f    straight             NaN                NaN
# 59942   24     single   m    straight             fit    mostly anything
# 59943   42     single   m    straight         average    mostly anything
# 59944   27     single   m    straight        athletic    mostly anything
# 59945   39     single   m         gay         average                NaN
#
#            drinks      drugs                          education  \
# ...

# %%
#Task 2: Explore the dataset to understand its structure.

df.head()
# Out:
#    age     status sex orientation       body_type               diet  \
# 0   22     single   m    straight  a little extra  strictly anything
# 1   35     single   m    straight         average       mostly other
# 2   38  available   m    straight            thin           anything
# 3   23     single   m    straight            thin         vegetarian
# 4   29     single   m    straight        athletic                NaN
#
#      drinks      drugs                          education  \
# 0  socially      never      working on college/university
# 1     often  sometimes              working on space camp
# 2  socially        NaN     graduated from masters program
# 3  socially        NaN      working on college/university
# 4  socially      never  graduated from college/university
#
#              ethnicity  ...  \
# 0         asian, white  ...
# 1                white  ...
# 2                  NaN  ...
# 3                white  ...
# 4  asian, black, other  ...
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59946 entries, 0 to 59945
# Data columns (total 31 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   age          59946 non-null  int64
#  1   status       59946 non-null  object
#  2   sex          59946 non-null  object
#  3   orientation  59946 non-null  object
#  4   body_type    54650 non-null  object
#  5   diet         35551 non-null  object
#  6   drinks       56961 non-null  object
#  7   drugs        45866 non-null  object
#  8   education    53318 non-null  object
#  9   ethnicity    54266 non-null  object
#  10  height       59943 non-null  float64
#  11  income       59946 non-null  int64
#  12  job          51748 non-null  object
#  13  last_online  59946 non-null  object
#  14  location     59946 non-null  object
#  15  offspring    24385 non-null  object
#  16  pets         40025 non-null  object
#  17  religion     39720 non-null  object
# ...

# %%
#getting the statistical understanding of the data

df.describe()
# Out:
#                 age        height          income
# count  59946.000000  59943.000000    59946.000000
# mean      32.340290     68.295281    20033.222534
# std        9.452779      3.994803    97346.192104
# min       18.000000      1.000000       -1.000000
# 25%       26.000000     66.000000       -1.000000
# 50%       30.000000     68.000000       -1.000000
# 75%       37.000000     71.000000       -1.000000
# max      110.000000     95.000000  1000000.000000

# %%
#checking the number of rows and columns in dataset

df.shape
# Out:
# (59946, 31)

# %%
#how to cross verify whether data is stored properly?
##get the unique values for the columns you have doubt

df['smokes'].nunique()
# Out:
# 5

# %%
df['smokes'].nunique
# Out:
# <bound method IndexOpsMixin.nunique of 0             sometimes
# 1                    no
# 2                    no
# 3                    no
# 4                    no
#               ...
# 59941                no
# 59942                no
# 59943                no
# 59944    trying to quit
# 59945         sometimes
# Name: smokes, Length: 59946, dtype: object>

# %%
df['location'].nunique()
# Out:
# 199

# %%
#counting of null values in data

df.isnull().sum()
# Out:
# age                0
# status             0
# sex                0
# orientation        0
# body_type       5296
# diet           24395
# drinks          2985
# drugs          14080
# education       6628
# ethnicity       5680
# height             3
# income             0
# job             8198
# last_online        0
# location           0
# offspring      35561
# pets           19921
# religion       20226
# sign           11056
# smokes          5512
# speaks            50
# essay0          5488
# essay1          7572
# essay2          9638
# essay3         11476
# essay4         10537
# essay5         10850
# essay6         13771
# essay7         12451
# essay8         19225
# essay9         12603
# dtype: int64

# %%
#Task 3: Visualize and describe the distribution of key variables like age, height, and income.

import seaborn as sns

# %%
sns.distplot(df['age'])
# Out:
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_19972/3234920688.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['age'])
# <Axes: xlabel='age', ylabel='Density'>

# %%
#graph depicting age 

import matplotlib.pyplot as plt

plt.figure(figsize=(25,8))
sns.countplot(x='age', data=df)
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
#graph depicting income 
sns.distplot(df['income'])
# Out:
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_19972/4226138263.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['income'])
# <Axes: xlabel='income', ylabel='Density'>

# %%
sns.displot(data=df, x="income",hue="sex", binwidth = 50000, multiple = "stack");
plt.xlabel("Income")
plt.ylabel("Frequency")
#plt.xlim(0, 200000)
plt.show()

##Most of the users have an income under 200 000. Males earn more than females.
# Out:
# /Users/yiting/Desktop/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
#graph depicting height 
sns.distplot(df['height'])
# Out:
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_19972/3273884657.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['height'])
# <Axes: xlabel='height', ylabel='Density'>

# %%
#Task 4: Explore categorical variables such as gender, body type, diet, drinks, drugs, education, etc.

df['sex'].nunique()
# Out:
# 2

# %%
##Task 4: Explore categorical variables such as gender, body type, diet, drinks, drugs, education, etc.
#check visually using single variable chart 

sns.countplot(x='sex', data=df)
## conclusion: more male than female using okcupid.
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
df['body_type'].nunique()
# Out:
# 12

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(25,8))

sns.countplot(x='body_type', data=df)

###conclusion: Most of the people responded that their body type is average.
# Out:
# <Axes: xlabel='body_type', ylabel='count'>

# %%
#body type as per gender

plt.figure(figsize=(25,8))

sns.countplot(x='body_type',hue='sex', data=df)

#most men tend to portray themselves as being athletic while most women say that they have average body type.
# Out:
# <Axes: xlabel='body_type', ylabel='count'>

# %%
df['drinks'].nunique()
# Out:
# 6

# %%
sns.countplot(x='drinks', data=df)
### Most people say that they are social drinkers.
# Out:
# <Axes: xlabel='drinks', ylabel='count'>

# %%
df['diet'].nunique()
# Out:
# 18

# %%
plt.figure(figsize=(30,15))
sns.countplot(x='diet', data=df)

# most users do not have preferences when eating.
# Out:
# <Axes: xlabel='diet', ylabel='count'>

# %%
plt.figure(figsize=(30,15))
sns.countplot(x='diet', hue='sex', data=df)

#when we check the diet by gender, women tend to be vegeterian as compared to men
# Out:
# <Axes: xlabel='diet', ylabel='count'>

# %%
#checking the unique values for zodiac sign

df['sign'].nunique()
# Out:
# 48

# %%
#there are 12 signs in zodiac, need to clean and make it into 12 types. 

plt.figure(figsize=(18,12))

sns.countplot(data=df, y="sign");

# %%
df['sign_new']=df['sign'].str.split().str[0]
df['sign_new']
# Out:
# 0             gemini
# 1             cancer
# 2             pisces
# 3             pisces
# 4           aquarius
#             ...
# 59941         cancer
# 59942            leo
# 59943    sagittarius
# 59944            leo
# 59945         gemini
# Name: sign_new, Length: 59946, dtype: object

# %%
sns.countplot(data=df, y="sign_new");

#most common sign is leo, least common is capricorn.

# %% [markdown]
# ##check the unique values for the categorial features, if have 10-15 category, use countplot to plot and draw insights

# %%
df['orientation'].nunique()
# Out:
# 3

# %%
plt.figure(figsize=(8,6))

sns.countplot(data=df, y="orientation");

#most users are straight.

# %%
df['drugs'].nunique()
# Out:
# 3

# %%
plt.figure(figsize=(8,6))

sns.countplot(data=df, y="drugs");

#overwhelming majority of the users do not use drugs.

# %%
df['education'].nunique()
# Out:
# 32

# %%
plt.figure(figsize=(8,6))

sns.countplot(data=df, y="education");

#a large number of users have graduated from college/university

# %%
df['ethnicity'].nunique()
# Out:
# 217

# %%
df['job'].nunique()
# Out:
# 21

# %%
##### job counts
df.job.value_counts()
# Out:
# job
# other                                7589
# student                              4882
# science / tech / engineering         4848
# computer / hardware / software       4709
# artistic / musical / writer          4439
# sales / marketing / biz dev          4391
# medicine / health                    3680
# education / academia                 3513
# executive / management               2373
# banking / financial / real estate    2266
# entertainment / media                2250
# law / legal services                 1381
# hospitality / travel                 1364
# construction / craftsmanship         1021
# clerical / administrative             805
# political / government                708
# rather not say                        436
# transportation                        366
# unemployed                            273
# retired                               250
# military                              204
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,6))

sns.countplot(data=df, y="job")

#most commmon job is others, implying that users don't really want to share their jobs
# Out:
# <Axes: xlabel='count', ylabel='job'>

# %%
df['last_online'].nunique()
# Out:
# 30123

# %%
df['location'].nunique()
# Out:
# 199

# %%
df['offspring'].nunique()
# Out:
# 15

# %%
plt.figure(figsize=(30,15))
sns.countplot(x='offspring', data=df)

## most users don't have kids.
# Out:
# <Axes: xlabel='offspring', ylabel='count'>

# %%
df['pets'].nunique()
# Out:
# 15

# %%
plt.figure(figsize=(30,15))
sns.countplot(x='pets', data=df)

#most users like cats and like dogs, they portray themselves as animal lovers but does not necessarily have pets.
# Out:
# <Axes: xlabel='pets', ylabel='count'>

# %%
df['religion'].nunique()
# Out:
# 45

# %%
plt.figure(figsize=(18,12))

sns.countplot(data=df, y="religion");

# %% [markdown]
# #By looking at the countplot of users' religion and calling value_counts function on this column, we find out that we can reduce the number of categories.

# %%
df.religion.value_counts(dropna=False)
# Out:
# religion
# NaN                                           20226
# agnosticism                                    2724
# other                                          2691
# agnosticism but not too serious about it       2636
# agnosticism and laughing about it              2496
# catholicism but not too serious about it       2318
# atheism                                        2175
# other and laughing about it                    2119
# atheism and laughing about it                  2074
# christianity                                   1957
# christianity but not too serious about it      1952
# other but not too serious about it             1554
# judaism but not too serious about it           1517
# atheism but not too serious about it           1318
# catholicism                                    1064
# christianity and somewhat serious about it      927
# atheism and somewhat serious about it           848
# other and somewhat serious about it             846
# ...

# %%
df['religion_cleaned'] = df['religion'].str.split().str[0]

print(df['religion_cleaned'].head())
# Out:
# 0    agnosticism
# 1    agnosticism
# 2            NaN
# 3            NaN
# 4            NaN
# Name: religion_cleaned, dtype: object

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, y="religion_cleaned");

# plot shows that most of the users are not religious.The majority of OKCupid's users are agnostic or atheist or did not mention their belief(other).
#Between religious users, most of them are christian.

# %%
df ['smokes'].nunique()
# Out:
# 5

# %%
plt.figure(figsize=(8,6))

sns.countplot(data=df, y="smokes");

#majority of users do not smoke.

# %%
df['status'].nunique()
# Out:
# 5

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, y="status");

#most users are single, which explains why they're using okcupid.

# %%
df['speaks'].nunique()
# Out:
# 7647

# %%
df.speaks.value_counts(dropna=False)
# Out:
# speaks
# english                                                                21828
# english (fluently)                                                      6628
# english (fluently), spanish (poorly)                                    2059
# english (fluently), spanish (okay)                                      1917
# english (fluently), spanish (fluently)                                  1288
#                                                                        ...
# english (fluently), urdu (poorly), japanese (poorly), french (okay)        1
# english, spanish, hindi, c++                                               1
# english (fluently), japanese (okay), thai (okay), chinese (poorly)         1
# english (fluently), french (okay), italian (okay), hebrew (okay)           1
# english (fluently), french, farsi                                          1
# Name: count, Length: 7648, dtype: int64

# %% [markdown]
# #Task 5: Summarize initial observations from data exploration.
#
# ##In OKcupid, there is a wide variety of users with various preferences, with the most common age group between 20 to 30plus.

# %% [markdown]
# ## Activity 2 - Data Cleaning and Preparation:

# %% [markdown]
# #Task 1: Handle missing values in the dataset.
# #Task 2: Convert categorical variables into numeric form.
# #Task 3: Address any data cleaning and preprocessing tasks.Normalization/transformation
# #Task 4: Prepare the data for analysis.
# #Task 5: Document data cleaning and preparation steps.

# %% [markdown]
# # Fill in missing values

# %%
#Task 1: Handle missing values in the dataset.


###Fill in the missing values for height. 
df ['height']=df['height'].fillna(df['height'].mean())
df
# Out:
#        age     status sex orientation       body_type               diet  \
# 0       22     single   m    straight  a little extra  strictly anything
# 1       35     single   m    straight         average       mostly other
# 2       38  available   m    straight            thin           anything
# 3       23     single   m    straight            thin         vegetarian
# 4       29     single   m    straight        athletic                NaN
# ...    ...        ...  ..         ...             ...                ...
# 59941   59     single   f    straight             NaN                NaN
# 59942   24     single   m    straight             fit    mostly anything
# 59943   42     single   m    straight         average    mostly anything
# 59944   27     single   m    straight        athletic    mostly anything
# 59945   39     single   m         gay         average                NaN
#
#            drinks      drugs                          education  \
# ...

# %%
##remove entire column if filled with null values, otherwise fill missing values. 
df.isnull().sum()
# Out:
# age                     0
# status                  0
# sex                     0
# orientation             0
# body_type            5296
# diet                24395
# drinks               2985
# drugs               14080
# education            6628
# ethnicity            5680
# height                  0
# income                  0
# job                  8198
# last_online             0
# location                0
# offspring           35561
# pets                19921
# religion            20226
# sign                11056
# smokes               5512
# speaks                 50
# essay0               5488
# essay1               7572
# essay2               9638
# essay3              11476
# essay4              10537
# essay5              10850
# essay6              13771
# essay7              12451
# essay8              19225
# essay9              12603
# sign_new            11056
# religion_cleaned    20226
# dtype: int64

# %%
round((df.isnull().sum()/59946)*100,2)

## remove the entire column if its filled with most of the null values otherwise fill the missing values 
### if your missing values is very less (< 2%) you can remove the rows as well.

### if missing values is less than 10%(1million) fill the values if its very less <5% simply delete the rows
## and if your column is having more than 10% of missing values delete column 


##Note:- we will always first try to fill the missing values because removing it removes the complete existence
### of that particular set of rows.
# Out:
# age                  0.00
# status               0.00
# sex                  0.00
# orientation          0.00
# body_type            8.83
# diet                40.69
# drinks               4.98
# drugs               23.49
# education           11.06
# ethnicity            9.48
# height               0.00
# income               0.00
# job                 13.68
# last_online          0.00
# location             0.00
# offspring           59.32
# pets                33.23
# religion            33.74
# sign                18.44
# smokes               9.19
# speaks               0.08
# essay0               9.15
# essay1              12.63
# essay2              16.08
# essay3              19.14
# essay4              17.58
# essay5              18.10
# essay6              22.97
# essay7              20.77
# essay8              32.07
# essay9              21.02
# sign_new            18.44
# religion_cleaned    33.74
# dtype: float64

# %%
#Fill in missing values

df ['body_type']=df['body_type'].fillna ('average')
df ['diet']=df['diet'].fillna('mostly anything')
df['job']=df['job'].fillna('others')

df['religion']=df['religion'].fillna('not available')
df['sign_new']=df['sign_new'].fillna('not available')
df['essay0']=df['essay0'].fillna('not available')
df['essay1']=df['essay1'].fillna('not available')
df['essay2']=df['essay2'].fillna('not available')
df['essay3']=df['essay3'].fillna('not available')
df['essay4']=df['essay4'].fillna('not available')
df['essay5']=df['essay5'].fillna('not available')
df['essay6']=df['essay6'].fillna('not available')
df['essay7']=df['essay7'].fillna('not available')
df['essay8']=df['essay8'].fillna('not available')
df['essay9']=df['essay9'].fillna('not available')

df['education']=df['education'].fillna('not available')
df['ethnicity']=df['ethnicity'].fillna('not available')
df['offspring']=df['offspring'].fillna('not available')
df['pets']=df['pets'].fillna('not available')
df['drugs']=df['drugs'].fillna('not available')
df['smokes']=df['smokes'].fillna('not available')

# %%
df=df.dropna(subset=['drinks','speaks'],axis =0)

# %%
round((df.isnull().sum()/59946)*100,2)
# Out:
# age                  0.00
# status               0.00
# sex                  0.00
# orientation          0.00
# body_type            0.00
# diet                 0.00
# drinks               0.00
# drugs                0.00
# education            0.00
# ethnicity            0.00
# height               0.00
# income               0.00
# job                  0.00
# last_online          0.00
# location             0.00
# offspring            0.00
# pets                 0.00
# religion             0.00
# sign                15.99
# smokes               0.00
# speaks               0.00
# essay0               0.00
# essay1               0.00
# essay2               0.00
# essay3               0.00
# essay4               0.00
# essay5               0.00
# essay6               0.00
# essay7               0.00
# essay8               0.00
# essay9               0.00
# sign_new             0.00
# religion_cleaned    30.40
# dtype: float64

# %%
df_old=df

# %%
#cleaning data
df['sign_new']=df['sign'].str.split().str[0]
df['sign_new']
# Out:
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_19972/3027090610.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['sign_new']=df['sign'].str.split().str[0]
# 0             gemini
# 1             cancer
# 2             pisces
# 3             pisces
# 4           aquarius
#             ...
# 59941         cancer
# 59942            leo
# 59943    sagittarius
# 59944            leo
# 59945         gemini
# Name: sign_new, Length: 56923, dtype: object

# %%
df.describe()
# Out:
#                 age        height          income
# count  56923.000000  56923.000000    56923.000000
# mean      32.399821     68.284613    20395.171530
# std        9.464067      3.977829    97651.036727
# min       18.000000      1.000000       -1.000000
# 25%       26.000000     66.000000       -1.000000
# 50%       30.000000     68.000000       -1.000000
# 75%       37.000000     71.000000       -1.000000
# max       69.000000     95.000000  1000000.000000

# %%
##converting from object to numeric 
#we have 28 columns
#for all need to check for number of unique values and apply label encoder/one hot encoder
##while checking for uniques, as per industry, up to 10 values for one hot encoder, otherwise, use label encoder 
#use for loop to change categorical to numerical at one go
#
#here we have enough number of features, already 30 features so we will use label encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 56923 entries, 0 to 59945
# Data columns (total 33 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               56923 non-null  int64
#  1   status            56923 non-null  object
#  2   sex               56923 non-null  object
#  3   orientation       56923 non-null  object
#  4   body_type         56923 non-null  object
#  5   diet              56923 non-null  object
#  6   drinks            56923 non-null  object
#  7   drugs             56923 non-null  object
#  8   education         56923 non-null  object
#  9   ethnicity         56923 non-null  object
#  10  height            56923 non-null  float64
#  11  income            56923 non-null  int64
#  12  job               56923 non-null  object
#  13  last_online       56923 non-null  object
#  14  location          56923 non-null  object
#  15  offspring         56923 non-null  object
# ...

# %%
df.isnull().sum()
# Out:
# age                     0
# status                  0
# sex                     0
# orientation             0
# body_type               0
# diet                    0
# drinks                  0
# drugs                   0
# education               0
# ethnicity               0
# height                  0
# income                  0
# job                     0
# last_online             0
# location                0
# offspring               0
# pets                    0
# religion                0
# sign                 9588
# smokes                  0
# speaks                  0
# essay0                  0
# essay1                  0
# essay2                  0
# essay3                  0
# essay4                  0
# essay5                  0
# essay6                  0
# essay7                  0
# essay8                  0
# essay9                  0
# sign_new             9588
# religion_cleaned    18224
# dtype: int64

# %%
df.shape
# Out:
# (56923, 33)

# %% [markdown]
# # Activity 3

# %% [markdown]
# Activity 3 - Zodiac Sign Prediction:
# • Task 1: Select relevant features for predicting Zodiac signs.
# • Task 2: Choose appropriate machine learning models.
# • Task 3: Train the selected models and evaluate their performance.
# • Task 4: Analyze results and draw conclusions.
# • Task 5: Compare the performance of different models (ANN, Decision Tree, SVC,
# Random Forest).

# %%
#Task 1: Select relevant features for predicting Zodiac signs.

# %% [markdown]
# We will predict Zodiac signs using 'body_type', 'diet', 'orientation', 'pets', 'religion_cleaned', 'sex', 'job', 'smokes', 'drinks' and 'drugs', 'education' features

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()


df['diet'] = label_encoder.fit_transform(df['diet'])
df['body_type'] = label_encoder.fit_transform(df['body_type'])
df['education'] = label_encoder.fit_transform(df['education'])
df['orientation'] = label_encoder.fit_transform(df['orientation'])
df['pets'] = label_encoder.fit_transform(df['pets'])
df['religion_cleaned'] = label_encoder.fit_transform(df['religion_cleaned'])
df['sex'] = label_encoder.fit_transform(df['sex'])
df['job'] = label_encoder.fit_transform(df['job'])
df['smokes'] = label_encoder.fit_transform(df['smokes'])
df['drinks'] = label_encoder.fit_transform(df['drinks'])
df['drugs'] = label_encoder.fit_transform(df['drugs'])



df['sign_new'] = label_encoder.fit_transform(df['sign_new'])
# Out:
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_19972/2853815509.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['diet'] = label_encoder.fit_transform(df['diet'])
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_19972/2853815509.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['body_type'] = label_encoder.fit_transform(df['body_type'])
# /var/folders/45/q5xntqvn17z3dzsttkthkkyh0000gn/T/ipykernel_19972/2853815509.py:7: SettingWithCopyWarning:
# ...

# %%
df['education']
# Out:
# 0        25
# 1        31
# 2        12
# 3        25
# 4         9
#          ..
# 59941     9
# 59942    25
# 59943    12
# 59944    25
# 59945    12
# Name: education, Length: 56923, dtype: int64

# %%
zodiac_columns= df[['body_type', 'education', 'diet', 'orientation', 'pets', 'religion_cleaned', 'sex', 'job', 'smokes', 'drinks','drugs']]

# %%
zodiac_columns
# Out:
#        body_type  education  diet  orientation  pets  religion_cleaned  sex  \
# 0              0         25    10            2    14                 0    1
# 1              2         31     6            2    14                 0    1
# 2             10         12     0            2     5                 9    1
# 3             10         25    17            2    10                 9    1
# 4              1          9     3            2    14                 9    1
# ...          ...        ...   ...          ...   ...               ...  ...
# 59941          2          9     3            2     6                 3    0
# 59942          4         25     3            2    14                 0    1
# 59943          2         12     3            2    15                 4    1
# 59944          1         25     3            2    14                 0    1
# 59945          2         12     3            1    14                 3    1
#
#        job  smokes  drinks  drugs
# ...

# %%
# Split the data into features (X) and target (y)
X = zodiac_columns
y = df['sign_new']

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, precision_score, recall_score, confusion_matrix


# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

#Pandas Series.ravel() function returns the flattened underlying data as an ndarray(1d array)
y_train = y_train.ravel()
y_test = y_test.ravel()

#use MinMaxScaler to put all features values in the same range and scale
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %% [markdown]
# #Task 2: Choose appropriate machine learning models.
# We chose some classification methods from scikit-learn library to predict class of test set samples.
# Classification methods should be able to do a multiclass classification. I used Multinomial Naive Bayes, LogisticRegression, DecisionTreeClassifiers and KNeighborsClassifier.

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB, GaussianNB
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

from sklearn.preprocessing import MinMaxScaler, StandardScaler

from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report, mean_squared_error, mean_absolute_error

# %% [markdown]
# #### Logistic Regression Model

# %%
logReg_model = LogisticRegression(multi_class= "multinomial")

logReg_model.fit(X_train_scaled, y_train)

training_accuracy = logReg_model.score(X_train_scaled, y_train)

print("The accuracy of model on training data is: {}%".format(round(training_accuracy, 2) *100))
print()

predictions = logReg_model.predict(X_test_scaled)

print(classification_report(y_test, predictions))
# Out:
# The accuracy of model on training data is: 17.0%
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       763
#            1       0.00      0.00      0.00       779
#            2       0.06      0.01      0.02       789
#            3       0.00      0.00      0.00       711
#            4       0.08      0.05      0.06       840
#            5       0.11      0.02      0.03       861
#            6       0.08      0.01      0.01       801
#            7       0.06      0.00      0.00       742
#            8       0.00      0.00      0.00       766
#            9       0.09      0.01      0.01       807
#           10       0.05      0.01      0.01       812
#           11       0.04      0.00      0.01       791
#           12       0.18      0.95      0.30      1923
#
#     accuracy                           0.17     11385
#    macro avg       0.06      0.08      0.04     11385
# ...

# %% [markdown]
# #### Random Forest Model

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Instantiate the Random Forest model
RFmodel = RandomForestClassifier()

# Fit the Random Forest model to the training data
RFmodel.fit(X_train_scaled, y_train)

# Calculate training accuracy
training_accuracy = RFmodel.score(X_train_scaled, y_train)

print("The accuracy of the model on training data is: {}%".format(round(training_accuracy, 2) * 100))
print()

# Make predictions on the test data
predictions = RFmodel.predict(X_test_scaled)

# Print classification report
print(classification_report(y_test, predictions))
# Out:
# The accuracy of the model on training data is: 91.0%
#
#               precision    recall  f1-score   support
#
#            0       0.07      0.06      0.07       763
#            1       0.07      0.06      0.07       779
#            2       0.08      0.08      0.08       789
#            3       0.06      0.05      0.05       711
#            4       0.07      0.07      0.07       840
#            5       0.08      0.07      0.08       861
#            6       0.07      0.06      0.07       801
#            7       0.07      0.06      0.06       742
#            8       0.07      0.05      0.06       766
#            9       0.08      0.07      0.07       807
#           10       0.10      0.08      0.09       812
#           11       0.07      0.06      0.06       791
#           12       0.28      0.45      0.35      1923
#
#     accuracy                           0.13     11385
#    macro avg       0.09      0.09      0.09     11385
# ...

# %% [markdown]
# We can see that by using naive bayes classifier and logistic regression, we get poor results.The accuracy of both models on test data are very low(17% and 13% respectively). This shows that these two classification methods are not suitable and we have underfitting problem.

# %% [markdown]
# #### Decision Tree Model

# %%
DTmodel = DecisionTreeClassifier()

DTmodel.fit(X_train_scaled, y_train)

training_accuracy = DTmodel.score(X_train_scaled, y_train)

print("The accuracy of model on training data is: {}%".format(round(training_accuracy, 2) *100))
print()

predictions = DTmodel.predict(X_test_scaled)

print(classification_report(y_test, predictions))
# Out:
# The accuracy of model on training data is: 91.0%
#
#               precision    recall  f1-score   support
#
#            0       0.06      0.07      0.06       763
#            1       0.07      0.08      0.08       779
#            2       0.07      0.07      0.07       789
#            3       0.07      0.07      0.07       711
#            4       0.09      0.10      0.10       840
#            5       0.06      0.06      0.06       861
#            6       0.08      0.08      0.08       801
#            7       0.07      0.07      0.07       742
#            8       0.05      0.05      0.05       766
#            9       0.07      0.06      0.07       807
#           10       0.09      0.08      0.08       812
#           11       0.07      0.07      0.07       791
#           12       0.28      0.27      0.27      1923
#
#     accuracy                           0.11     11385
#    macro avg       0.09      0.09      0.09     11385
# ...

# %% [markdown]
# #### ANN

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Assuming you have X_train, X_test, y_train, y_test, X_train_scaled, and X_test_scaled already defined

# Instantiate the MLPClassifier
ANNmodel = MLPClassifier(max_iter=1000)  # You may need to adjust max_iter based on convergence

# Fit the ANN model to the training data
ANNmodel.fit(X_train_scaled, y_train)

# Calculate training accuracy
training_accuracy = ANNmodel.score(X_train_scaled, y_train)

print("The accuracy of the model on training data is: {}%".format(round(training_accuracy, 2) * 100))
print()

# Make predictions on the test data
predictions = ANNmodel.predict(X_test_scaled)

# Print classification report
print(classification_report(y_test, predictions))
# Out:
# The accuracy of the model on training data is: 19.0%
#
#               precision    recall  f1-score   support
#
#            0       0.13      0.02      0.04       763
#            1       0.07      0.03      0.04       779
#            2       0.08      0.07      0.07       789
#            3       0.11      0.02      0.03       711
#            4       0.08      0.04      0.05       840
#            5       0.11      0.05      0.07       861
#            6       0.06      0.03      0.04       801
#            7       0.10      0.03      0.05       742
#            8       0.07      0.03      0.04       766
#            9       0.07      0.01      0.01       807
#           10       0.08      0.04      0.05       812
#           11       0.09      0.07      0.07       791
#           12       0.22      0.84      0.35      1923
#
#     accuracy                           0.17     11385
#    macro avg       0.10      0.10      0.07     11385
# ...

# %% [markdown]
# The accuracy of decision tree model on training data is 91% which is very high, but on test data it performs very badly with a 10% accuracy. This shows that decision tree model suffers from overfitting. Meanwhile, the ANN model performed badly in both training and test data accuracy (19% and 17% respectively).
#
# Overall, for Task 3, if we are to guess the zodiac sign of user, the probability of guessing correct is 1/12 (8.3%).This showed that the models that I trained above did not significantly outperform random guessing since most of them have an accuracy that is slightly higher at only 9%.
#
# So we can conclude that by using 'body_type', 'diet', 'education','orientation', 'pets', 'religion_cleaned', 'sex', 'job', 'smokes', 'drinks' and 'drugs', we cannot predict the zodiac sign of the user.

# %% [markdown]
# # Activity 4 - Body Type Prediction

# %% [markdown]
# • Task 1: Select features for predicting body type.
# • Task 2: Choose machine learning models.
# • Task 3: Train the models and evaluate their performance.
# • Task 4: Analyze results and draw conclusions.
# • Task 5: Compare the performance of different models (ANN, Decision Tree, SVC,
# Random Forest).

# %% [markdown]
# #Use lifestyle information ('diet', 'smokes_code', 'drinks_code', 'drugs_code'), sex and age to predict body type

# %%
#Select features for predicting body type.


bodytype_columns= df[['diet', 'age', 'sex', 'smokes', 'drinks','drugs']]

# %%
bodytype_columns
# Out:
#        diet  age  sex  smokes  drinks  drugs
# 0        10   22    1       2       4      0
# 1         6   35    1       0       2      3
# 2         0   38    1       0       4      1
# 3        17   23    1       0       4      1
# 4         3   29    1       0       4      0
# ...     ...  ...  ...     ...     ...    ...
# 59941     3   59    0       0       4      0
# 59942     3   24    1       0       2      3
# 59943     3   42    1       0       1      0
# 59944     3   27    1       3       4      2
# 59945     3   39    1       2       4      1
#
# [56923 rows x 6 columns]

# %%
X = bodytype_columns
y = df['body_type']

#Split the data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

#Pandas Series.ravel() function returns the flattened underlying data as an ndarray(1d array)
y_train = y_train.ravel()
y_test = y_test.ravel()

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %% [markdown]
# After data splitting, I will use 5 different classifiers for analysis: Logistic Regression, Random Forest, Decision Tree, Support Vector Machine and ANN

# %% [markdown]
# #### Logistic Regression

# %%
logReg_model = LogisticRegression(multi_class= "multinomial")

logReg_model.fit(X_train_scaled, y_train)

training_accuracy = logReg_model.score(X_train_scaled, y_train)

print("The accuracy of model on training data is: {}%".format(round(training_accuracy, 2) *100))
print()

predictions = logReg_model.predict(X_test_scaled)

print(classification_report(y_test, predictions))

#The accuracy on both training data and test data is 33%.
# Out:
# The accuracy of model on training data is: 33.0%
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       517
#            1       0.32      0.27      0.29      2207
#            2       0.34      0.81      0.48      3767
#            3       0.00      0.00      0.00       777
#            4       0.29      0.06      0.10      2437
#            5       0.00      0.00      0.00       211
#            6       0.00      0.00      0.00        86
#            7       0.00      0.00      0.00        78
#            8       0.00      0.00      0.00        37
#            9       0.00      0.00      0.00       313
#           10       0.00      0.00      0.00       883
#           11       0.00      0.00      0.00        72
#
#     accuracy                           0.33     11385
#    macro avg       0.08      0.10      0.07     11385
# weighted avg       0.24      0.33      0.24     11385
# ...

# %% [markdown]
# #### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import numpy as np


# Initialize an empty list to store accuracies
accuracies = []

# Range of values for the number of trees in the forest
n_estimators_list = list(range(1, 11))

# Loop through different values for the number of trees
for n_estimators in n_estimators_list:
    RFmodel = RandomForestClassifier(n_estimators=n_estimators, random_state=42)
    RFmodel.fit(X_train_scaled, y_train)
    accuracies.append(RFmodel.score(X_test_scaled, y_test))

# Plot the accuracy vs. the number of trees
plt.plot(n_estimators_list, accuracies)
plt.xlabel("Number of Trees")
plt.ylabel("Test set Accuracy")
plt.title("Accuracy of Model on Test Set")
plt.show()

# Convert the accuracies to a numpy array for easier analysis
accuracies_np = np.asarray(accuracies)

# Find the best number of trees for the highest accuracy
best_n_estimators = n_estimators_list[np.argmax(accuracies_np)]
print(f"Best number of trees for the best accuracy is: {best_n_estimators}")
# Out:
# Best number of trees for the best accuracy is: 5

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report


# Initialize the Random Forest model with the best number of estimators
RFmodel = RandomForestClassifier(n_estimators=5, random_state=42)

# Fit the model on the training data
RFmodel.fit(X_train_scaled, y_train)

# Calculate and print the training accuracy
training_accuracy = RFmodel.score(X_train_scaled, y_train)
print("The accuracy of the model on training data is: {:.2%}".format(training_accuracy))
print()

# Make predictions on the test data
predictions = RFmodel.predict(X_test_scaled)

# Print the classification report
print(classification_report(y_test, predictions))

#Model accuarcy on trainig data is 45.7% while accuracy is 29% for test data.
# Out:
# The accuracy of the model on training data is: 45.65%
#
#               precision    recall  f1-score   support
#
#            0       0.10      0.04      0.05       517
#            1       0.30      0.35      0.32      2207
#            2       0.34      0.53      0.41      3767
#            3       0.19      0.11      0.14       777
#            4       0.24      0.18      0.20      2437
#            5       0.05      0.01      0.02       211
#            6       0.00      0.00      0.00        86
#            7       0.00      0.00      0.00        78
#            8       0.00      0.00      0.00        37
#            9       0.08      0.03      0.04       313
#           10       0.10      0.04      0.05       883
#           11       0.04      0.01      0.02        72
#
#     accuracy                           0.29     11385
#    macro avg       0.12      0.11      0.11     11385
# weighted avg       0.25      0.29      0.26     11385

# %% [markdown]
# #### Decision Tree
# ##### Accuracy is 34% for training data and 33% for test data.

# %%
param_grid = {"max_depth": [8, 12, 18, 24, None],
              "min_samples_leaf": range(1, 9),
              "criterion": ["gini", "entropy"]}

DTmodel = DecisionTreeClassifier()

tree_cv = GridSearchCV(DTmodel, param_grid, cv = 5)

tree_cv.fit(X_train_scaled, y_train)

# Print the tuned parameters and score
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_))
print("Best score is {}".format(tree_cv.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 6}
# Best score is 0.32809961633608997

# %%
DTmodel = DecisionTreeClassifier(criterion =  'entropy' , max_depth =  8, min_samples_leaf = 6)

DTmodel.fit(X_train_scaled, y_train)

training_accuracy = DTmodel.score(X_train_scaled, y_train)

print("The accuracy of model on training data is: {}%".format(round(training_accuracy, 2) *100))
print()

predictions = DTmodel.predict(X_test_scaled)

print(classification_report(y_test, predictions))

print(DTmodel.get_depth())
# Out:
# The accuracy of model on training data is: 34.0%
#
#               precision    recall  f1-score   support
#
#            0       0.06      0.00      0.00       517
#            1       0.31      0.45      0.37      2207
#            2       0.34      0.68      0.46      3767
#            3       0.16      0.02      0.03       777
#            4       0.25      0.06      0.09      2437
#            5       0.25      0.00      0.01       211
#            6       0.00      0.00      0.00        86
#            7       0.00      0.00      0.00        78
#            8       0.00      0.00      0.00        37
#            9       0.08      0.00      0.01       313
#           10       0.07      0.00      0.00       883
#           11       0.00      0.00      0.00        72
#
#     accuracy                           0.33     11385
#    macro avg       0.13      0.10      0.08     11385
# weighted avg       0.25      0.33      0.25     11385
#
# 8
# ...

# %% [markdown]
# #### SVC

# %% [markdown]
# In this model, both training data and test data have an accuracy of 33%.

# %%
param_grid = {'C': [0.1],
              'gamma': [0.1],
              'kernel': ['linear']}

SVCmodel = SVC()

svm_cv = GridSearchCV(SVCmodel, param_grid, cv = 3)

svm_cv.fit(X_train, y_train)

# Print the tuned parameters and score
print("Tuned Support Vector Machine classifier Parameters: {}".format(svm_cv.best_params_))
print("Best score is {}".format(svm_cv.best_score_))
# Out:
# Tuned Support Vector Machine classifier Parameters: {'C': 0.1, 'gamma': 0.1, 'kernel': 'linear'}
# Best score is 0.32825332672618823

# %%
SVCmodel = SVC(kernel = 'rbf', C = 0.1, gamma = 1)

SVCmodel.fit(X_train_scaled, y_train)

training_accuracy = SVCmodel.score(X_train_scaled, y_train)

print("The accuracy of model on training data is: {}%".format(round(training_accuracy, 2) *100))
print()

predictions = SVCmodel.predict(X_test_scaled)

print(classification_report(y_test, predictions))
# Out:
# The accuracy of model on training data is: 33.0%
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       517
#            1       1.00      0.00      0.00      2207
#            2       0.33      1.00      0.50      3767
#            3       0.00      0.00      0.00       777
#            4       0.00      0.00      0.00      2437
#            5       0.00      0.00      0.00       211
#            6       0.00      0.00      0.00        86
#            7       0.00      0.00      0.00        78
#            8       0.00      0.00      0.00        37
#            9       0.00      0.00      0.00       313
#           10       0.00      0.00      0.00       883
#           11       0.00      0.00      0.00        72
#
#     accuracy                           0.33     11385
#    macro avg       0.11      0.08      0.04     11385
# weighted avg       0.30      0.33      0.16     11385
# ...

# %% [markdown]
# #### ANN

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report


# Initialize the MLPClassifier model
ANNmodel = MLPClassifier(random_state=42)

# Fit the model on the training data
ANNmodel.fit(X_train, y_train)

# Make predictions on the test set
ANN_predictions = ANNmodel.predict(X_test)

# Print the classification report
print(classification_report(y_test, ANN_predictions))
print()

# Calculate and print the accuracy on the training data
training_accuracy = ANNmodel.score(X_train, y_train)
print("The accuracy of the model on training data is: {}%".format(round(training_accuracy, 2) * 100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       517
#            1       0.32      0.50      0.39      2207
#            2       0.35      0.67      0.46      3767
#            3       0.20      0.00      0.01       777
#            4       0.27      0.07      0.11      2437
#            5       0.00      0.00      0.00       211
#            6       0.17      0.01      0.02        86
#            7       0.00      0.00      0.00        78
#            8       0.00      0.00      0.00        37
#            9       0.00      0.00      0.00       313
#           10       0.00      0.00      0.00       883
#           11       0.33      0.01      0.03        72
#
#     accuracy                           0.33     11385
#    macro avg       0.14      0.11      0.08     11385
# weighted avg       0.25      0.33      0.25     11385
#
#
# The accuracy of the model on training data is: 33.0%
# ...

# %% [markdown]
# We can see that all of five models have approximately the same range of accuracy.Their accuracy on both training set and test set is about 30plus%.
#
# All models have the accuracy under 50% and this tells us that 'diet', 'smokes', 'drinks', 'drugs, sex and age cannot be used to predict body type.

# %% [markdown]
# # Activity 5 - Income Prediction

# %% [markdown]
# Task 1: Investigate the income column and handle missing or invalid values.
# • Task 2: Select relevant features for predicting income.
# • Task 3: Choose machine learning models and tune hyperparameters.
# • Task 4: Evaluate model performance.
# • Task 5: Analyze results and draw conclusions (and compare the performance of
# different models).

# %% [markdown]
# Can we predict income of users using "job", "sex" and "education"? Using Random forest, Decision Tree models

# %%
df1= pd.read_csv('profiles.csv')

df1
# Out:
#        age     status sex orientation       body_type               diet  \
# 0       22     single   m    straight  a little extra  strictly anything
# 1       35     single   m    straight         average       mostly other
# 2       38  available   m    straight            thin           anything
# 3       23     single   m    straight            thin         vegetarian
# 4       29     single   m    straight        athletic                NaN
# ...    ...        ...  ..         ...             ...                ...
# 59941   59     single   f    straight             NaN                NaN
# 59942   24     single   m    straight             fit    mostly anything
# 59943   42     single   m    straight         average    mostly anything
# 59944   27     single   m    straight        athletic    mostly anything
# 59945   39     single   m         gay         average                NaN
#
#            drinks      drugs                          education  \
# ...

# %%
df1.income
# Out:
# 0            -1
# 1         80000
# 2            -1
# 3         20000
# 4            -1
#           ...
# 59941        -1
# 59942        -1
# 59943    100000
# 59944        -1
# 59945        -1
# Name: income, Length: 59946, dtype: int64

# %%
df1[df1.income==-1]= np.nan

df1.income.value_counts(dropna = False)
# Out:
# income
# NaN          48442
# 20000.0       2952
# 100000.0      1621
# 80000.0       1111
# 30000.0       1048
# 40000.0       1005
# 50000.0        975
# 60000.0        736
# 70000.0        707
# 150000.0       631
# 1000000.0      521
# 250000.0       149
# 500000.0        48
# Name: count, dtype: int64

# %%
selected_features = ['income', 'job', 'sex', 'education']
df1 = df1 [selected_features].dropna()

#convert 'job', 'sex' and 'education' into dummy variables
categoricalCols = ['job', 'sex', 'education']

for col in categoricalCols:
    df1 = pd.get_dummies(df1, columns=[col], prefix = [col], drop_first =True)

print(df1.shape)

df1.head()
# Out:
# (10536, 52)
#      income  job_banking / financial / real estate  \
# 1   80000.0                                  False
# 3   20000.0                                  False
# 11  40000.0                                   True
# 13  30000.0                                  False
# 14  50000.0                                  False
#
#     job_clerical / administrative  job_computer / hardware / software  \
# 1                           False                               False
# 3                           False                               False
# 11                          False                               False
# 13                          False                               False
# 14                          False                               False
#
#     job_construction / craftsmanship  job_education / academia  \
# 1                              False                     False
# 3                              False                     False
# ...

# %%
#Y is the target column, X has the features
X = df1.iloc[:, 1:]
y = df1['income']

#Split the data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

#Pandas Series.ravel() function returns the flattened underlying data as an ndarray(1d array)
y_train = y_train.ravel()
y_test = y_test.ravel()

# %% [markdown]
# #### Random forest
# Accuracy is 35%.

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have X_train, X_test, y_train, y_test already defined

# Define the range of estimators
n_estimators_list = list(range(1, 11))

# Initialize lists to store accuracies
accuracies = []

# Iterate through different number of estimators
for n_estimators in n_estimators_list:
    # Initialize the Random Forest model
    RFmodel = RandomForestClassifier(n_estimators=n_estimators, random_state=42)

    # Fit the model on the training data
    RFmodel.fit(X_train, y_train)

    # Append the accuracy on the test set to the list
    accuracies.append(RFmodel.score(X_test, y_test))

# Plot the accuracy vs the number of estimators
plt.plot(n_estimators_list, accuracies)
plt.xlabel("Number of Estimators")
plt.ylabel("Test Set Accuracy")
plt.title("Accuracy of Model on Test Set")
plt.show()

# Convert accuracies to a numpy array for further analysis
l_np = np.asarray(accuracies)

# Find the best number of estimators for the best accuracy
best_n_estimators = n_estimators_list[np.argmax(l_np)]
print(f"Best number of estimators for the best accuracy is: {best_n_estimators}")
# Out:
# Best number of estimators for the best accuracy is: 9

# %%
from sklearn.ensemble import RandomForestClassifier

# Assuming you have X_train, X_test, y_train, y_test already defined

# Set the best number of estimators
best_n_estimators = 9

# Initialize the Random Forest model with the best number of estimators
RFmodel = RandomForestClassifier(n_estimators=best_n_estimators, random_state=42)

# Fit the model on the training data
RFmodel.fit(X_train, y_train)

# Make predictions on the test set
RF_predictions = RFmodel.predict(X_test)

print(classification_report(y_test, RF_predictions))
# Out:
#               precision    recall  f1-score   support
#
#      20000.0       0.49      0.82      0.61       537
#      30000.0       0.12      0.03      0.05       177
#      40000.0       0.14      0.06      0.09       186
#      50000.0       0.19      0.13      0.16       171
#      60000.0       0.02      0.01      0.01       122
#      70000.0       0.18      0.06      0.09       147
#      80000.0       0.18      0.08      0.11       208
#     100000.0       0.30      0.65      0.41       302
#     150000.0       0.22      0.15      0.18       131
#     250000.0       0.14      0.04      0.07        23
#     500000.0       0.00      0.00      0.00        11
#    1000000.0       0.19      0.09      0.12        93
#
#     accuracy                           0.35      2108
#    macro avg       0.18      0.18      0.16      2108
# weighted avg       0.26      0.35      0.27      2108
# ...

# %% [markdown]
# #### Decision Tree
# Accuracy on training data is 39% while accuracy for test data is 34%.

# %%
param_grid = {"max_depth": [8, 12, 18, 24, None],
              "min_samples_leaf": range(1, 9),
              "criterion": ["gini", "entropy"]}

DTmodel = DecisionTreeClassifier()

tree_cv = GridSearchCV(DTmodel, param_grid, cv = 5)

tree_cv.fit(X_train, y_train)

# Print the tuned parameters and score
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_))
print("Best score is {}".format(tree_cv.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'criterion': 'gini', 'max_depth': 18, 'min_samples_leaf': 3}
# Best score is 0.3580931462101932

# %%
DTmodel = DecisionTreeClassifier(criterion =  'gini' , max_depth =  18, min_samples_leaf = 3)

DTmodel.fit(X_train, y_train)

training_accuracy = DTmodel.score(X_train, y_train)

print("The accuracy of model on training data is: {}%".format(round(training_accuracy, 2) *100))
print()

predictions = DTmodel.predict(X_test)

print(classification_report(y_test, predictions))
# Out:
# The accuracy of model on training data is: 39.0%
#
#               precision    recall  f1-score   support
#
#      20000.0       0.43      0.89      0.58       537
#      30000.0       0.09      0.02      0.03       177
#      40000.0       0.17      0.05      0.08       186
#      50000.0       0.17      0.10      0.12       171
#      60000.0       0.00      0.00      0.00       122
#      70000.0       0.22      0.01      0.03       147
#      80000.0       0.20      0.03      0.06       208
#     100000.0       0.30      0.63      0.41       302
#     150000.0       0.23      0.12      0.16       131
#     250000.0       0.00      0.00      0.00        23
#     500000.0       0.00      0.00      0.00        11
#    1000000.0       0.13      0.02      0.04        93
#
#     accuracy                           0.34      2108
#    macro avg       0.16      0.16      0.12      2108
# weighted avg       0.24      0.34      0.24      2108
# ...

# %% [markdown]
# #### SVC

# %%
SVCmodel = SVC(kernel = 'linear', C = 1)

SVCmodel.fit(X_train, y_train)

training_accuracy = SVCmodel.score(X_train, y_train)

print("The accuracy of model on training data is: {}%".format(round(training_accuracy, 2) *100))
print()

predictions = SVCmodel.predict(X_test)

print(classification_report(y_test, predictions))
# Out:
# The accuracy of model on training data is: 37.0%
#
#               precision    recall  f1-score   support
#
#      20000.0       0.48      0.88      0.62       537
#      30000.0       0.11      0.01      0.01       177
#      40000.0       0.14      0.03      0.05       186
#      50000.0       0.16      0.12      0.13       171
#      60000.0       0.10      0.02      0.03       122
#      70000.0       0.13      0.01      0.02       147
#      80000.0       0.20      0.08      0.11       208
#     100000.0       0.29      0.77      0.42       302
#     150000.0       0.25      0.02      0.03       131
#     250000.0       0.00      0.00      0.00        23
#     500000.0       0.00      0.00      0.00        11
#    1000000.0       0.08      0.02      0.03        93
#
#     accuracy                           0.36      2108
#    macro avg       0.16      0.16      0.12      2108
# weighted avg       0.25      0.36      0.25      2108
# ...

# %% [markdown]
# #### Logistic Regression

# %%
logReg_model = LogisticRegression(multi_class= "multinomial")

logReg_model.fit(X_train, y_train)

training_accuracy = logReg_model.score(X_train, y_train)

print("The accuracy of model on training data is: {}%".format(round(training_accuracy, 2) *100))
print()

predictions = logReg_model.predict(X_test)

print(classification_report(y_test, predictions))
# Out:
# The accuracy of model on training data is: 37.0%
#
#               precision    recall  f1-score   support
#
#      20000.0       0.47      0.88      0.61       537
#      30000.0       0.14      0.03      0.05       177
#      40000.0       0.10      0.01      0.02       186
#      50000.0       0.19      0.10      0.13       171
#      60000.0       0.00      0.00      0.00       122
#      70000.0       0.09      0.01      0.01       147
#      80000.0       0.17      0.07      0.10       208
#     100000.0       0.29      0.73      0.41       302
#     150000.0       0.21      0.10      0.14       131
#     250000.0       0.00      0.00      0.00        23
#     500000.0       0.00      0.00      0.00        11
#    1000000.0       0.24      0.04      0.07        93
#
#     accuracy                           0.36      2108
#    macro avg       0.16      0.16      0.13      2108
# weighted avg       0.24      0.36      0.25      2108
# ...

# %% [markdown]
# Both SVC and Logistic Regression have training data accuarcy of 37% and test data accuracy of 36%. All the four models range from 34-36% in their accuracy. This range of accuracy, under 50%, tells us that we can not predict the income of user by his job, sex and education.

# %% [markdown]
# # Activity 6 - Sex Prediction based on body type and height vis-a-vis Sex Prediction based on Education Level and Income:

# %% [markdown]
# # Sex Prediction based on body type and height

# %%
df2 = df

# %%
selected_features = ['sex', 'body_type', 'height']
df2 = df2[selected_features].dropna()

#height and 'body_type'

#convert 'body_type' into dummy variable
df2 = pd.get_dummies(df2, columns=['body_type'], prefix = ['body_type'])

print(df2.shape)

df2.head()
# Out:
# (56923, 14)
#    sex    height  body_type_0  body_type_1  body_type_2  body_type_3  \
# 0    1  1.678416         True        False        False        False
# 1    1  0.426749        False        False         True        False
# 2    1 -0.073919        False        False        False        False
# 3    1  0.677082        False        False        False        False
# 4    1 -0.574586        False         True        False        False
#
#    body_type_4  body_type_5  body_type_6  body_type_7  body_type_8  \
# 0        False        False        False        False        False
# 1        False        False        False        False        False
# 2        False        False        False        False        False
# 3        False        False        False        False        False
# 4        False        False        False        False        False
#
#    body_type_9  body_type_10  body_type_11
# 0        False         False         False
# 1        False         False         False
# ...

# %%
#Y is the target column, X has the features
X = df2.iloc[:, 1:]
y = df2['sex']

#Split the data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

#Pandas Series.ravel() function returns the flattened underlying data as an ndarray(1d array)
y_train = y_train.ravel()
y_test = y_test.ravel()

scaler = StandardScaler()

# standardization
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

scaler2 = MinMaxScaler()

# normalization
X_train_normalized = scaler2.fit_transform(X_train)
X_test_normalized = scaler2.fit_transform(X_test)

# %% [markdown]
# #### ANN

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report


# Initialize the MLPClassifier model
ANNmodel = MLPClassifier(random_state=42)

# Fit the model on the training data
ANNmodel.fit(X_train_normalized, y_train)

# Make predictions on the test set
ANN_predictions = ANNmodel.predict(X_test_normalized)

# Print the classification report
print(classification_report(y_test, ANN_predictions))
print()

# Calculate and print the accuracy on the training data
training_accuracy = ANNmodel.score(X_train_normalized, y_train)
print("The accuracy of the model on training data is: {}%".format(round(training_accuracy, 2) * 100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.93      0.79      4648
#            1       0.93      0.70      0.80      6737
#
#     accuracy                           0.80     11385
#    macro avg       0.81      0.82      0.79     11385
# weighted avg       0.83      0.80      0.80     11385
#
#
# The accuracy of the model on training data is: 85.0%

# %% [markdown]
# #### Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
import numpy as np
import matplotlib.pyplot as plt

# Assuming you have X_train_scaled, X_test_scaled, y_train, and y_test already defined

accuracies = []
estimator_list = list(range(1, 101))

for n_estimators in estimator_list:
    RandomForestModel = RandomForestClassifier(n_estimators=n_estimators, random_state=42)
    RandomForestModel.fit(X_train_scaled, y_train)
    accuracies.append(RandomForestModel.score(X_test_scaled, y_test))

# Plotting the accuracy vs. number of estimators
plt.plot(estimator_list, accuracies)
plt.xlabel("Number of Estimators")
plt.ylabel("Test set Accuracy")
plt.title("Accuracy of Model on Test Set for Random Forest")
plt.show()

# Finding the best number of estimators
np_accuracies = np.asarray(accuracies)
best_n_estimators = np_accuracies.argmax() + 1
print(f"Best number of estimators for the best accuracy is: {best_n_estimators}")
# Out:
# Best number of estimators for the best accuracy is: 2

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

# Assuming you have X_train_scaled, X_test_scaled, y_train, and y_test already defined

# Create a Random Forest model with 9 estimators
RandomForestModel = RandomForestClassifier(n_estimators=2, random_state=42)
RandomForestModel.fit(X_train_scaled, y_train)

# Make predictions on the test set
RandomForest_predictions = RandomForestModel.predict(X_test_scaled)

# Calculate training accuracy
training_accuracy = RandomForestModel.score(X_train_scaled, y_train)
print("The accuracy of the model on the training data is: {:.2f}%".format(training_accuracy * 100))
print()

# Display classification report
print("Classification Report:")
print(classification_report(y_test, RandomForest_predictions))


print("The accuracy of model on training data is: {}%".format(round(training_accuracy, 2) *100))
# Out:
# The accuracy of the model on the training data is: 85.37%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.76      0.81      4648
#            1       0.85      0.91      0.88      6737
#
#     accuracy                           0.85     11385
#    macro avg       0.85      0.84      0.84     11385
# weighted avg       0.85      0.85      0.85     11385
#
# The accuracy of model on training data is: 85.0%

# %% [markdown]
# #### Decision Tree

# %%
param_grid = {"max_depth": [8],
              "min_samples_leaf": list(range(1, 3)),
              "criterion": ["entropy"]}

DTmodel = DecisionTreeClassifier()

tree_cv = GridSearchCV(DTmodel, param_grid, cv = 5)

tree_cv.fit(X_train_scaled, y_train)

# Print the tuned parameters and score
print("Tuned Decision Tree Parameters: {}".format(tree_cv.best_params_))
print("Best score is {}".format(tree_cv.best_score_))
# Out:
# Tuned Decision Tree Parameters: {'criterion': 'entropy', 'max_depth': 8, 'min_samples_leaf': 1}
# Best score is 0.852452945725679

# %%
DTmodel = DecisionTreeClassifier(criterion = 'entropy', max_depth = 8, min_samples_leaf = 1)

DTmodel.fit(X_train_scaled, y_train)

training_accuracy = DTmodel.score(X_train_scaled, y_train)

predictions = DTmodel.predict(X_test_scaled)

print(classification_report(y_test, predictions))


print("The accuracy of model on training data is: {}%".format(round(training_accuracy, 2) *100))

#print(DTmodel.get_depth())
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.76      0.81      4648
#            1       0.85      0.91      0.88      6737
#
#     accuracy                           0.85     11385
#    macro avg       0.85      0.84      0.84     11385
# weighted avg       0.85      0.85      0.85     11385
#
# The accuracy of model on training data is: 85.0%

# %% [markdown]
# #### SVC

# %%
SVCmodel = SVC(kernel = 'linear', C = 1)

SVCmodel.fit(X_train_scaled, y_train)

training_accuracy = SVCmodel.score(X_train_scaled, y_train)

predictions = SVCmodel.predict(X_test_scaled)

print(classification_report(y_test, predictions))



print("The accuracy of model on training data is: {}%".format(round(training_accuracy, 2) *100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.81      0.81      4648
#            1       0.87      0.87      0.87      6737
#
#     accuracy                           0.85     11385
#    macro avg       0.84      0.84      0.84     11385
# weighted avg       0.85      0.85      0.85     11385
#
# The accuracy of model on training data is: 85.0%

# %% [markdown]
# #### Logistic Regression

# %%
logReg_model = LogisticRegression(multi_class= "multinomial")

logReg_model.fit(X_train_scaled, y_train)

training_accuracy = logReg_model.score(X_train_scaled, y_train)

predictions = logReg_model.predict(X_test_scaled)

print(classification_report(y_test, predictions))



print("The accuracy of model on training data is: {}%".format(round(training_accuracy, 2) *100))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.76      0.81      4648
#            1       0.85      0.91      0.88      6737
#
#     accuracy                           0.85     11385
#    macro avg       0.85      0.84      0.84     11385
# weighted avg       0.85      0.85      0.85     11385
#
# The accuracy of model on training data is: 85.0%

# %% [markdown]
# For this part we use 5 models: Multinomial Naive Bayes, K Nearest Neighbor, Decision Tree Classifier, Support Vector Machine and Logistic Regression.For all models, a good result of 85% is obtained.
#
# All the five algorithms have a very good accuracy and showed that we can use height and body type to predict the sex of the user.

# %% [markdown]
# # Activity 6: Sex Prediction based on Education Level and Income

# %% [markdown]
# Task 1: Create a copy of the original dataset and select relevant features.
# • Task 2: Replace missing values and convert education into dummy variables.
# • Task 3: Split the data into training and test sets.
# • Task 4: Train machine learning models and normalize features.
# • Task 5: Evaluate the accuracy of each model on the test set (ANN, Decision Tree,
# SVC, Random Forest).

# %%
df3= pd.read_csv('profiles.csv')
# Out:
# 0            -1
# 1         80000
# 2            -1
# 3         20000
# 4            -1
#           ...
# 59941        -1
# 59942        -1
# 59943    100000
# 59944        -1
# 59945        -1
# Name: income, Length: 59946, dtype: int64

# %%
#replace -1 values with nan
df3[df3.income==-1]= np.nan

# %%
selected_features = ['sex', 'education', 'income']
df3 = df3[selected_features].dropna()

#convert 'education' into dummy variable
df3 = pd.get_dummies(df3, columns=['education'], prefix = ['education'])


df3.head()
# Out:
#    sex   income  education_college/university  \
# 1    m  80000.0                         False
# 3    m  20000.0                         False
# 11   m  40000.0                         False
# 13   f  30000.0                         False
# 14   f  50000.0                         False
#
#     education_dropped out of college/university  \
# 1                                         False
# 3                                         False
# 11                                        False
# 13                                        False
# 14                                        False
#
#     education_dropped out of high school  education_dropped out of law school  \
# 1                                  False                                False
# 3                                  False                                False
# 11                                 False                                False
# ...

# %%
#Y is the target column, X has the features
X = df3.iloc[:, 1:]
y = df3['sex']

#Split the data into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state = 0)

#Pandas Series.ravel() function returns the flattened underlying data as an ndarray(1d array)
y_train = y_train.ravel()
y_test = y_test.ravel()

#scaler = StandardScaler()

scaler = MinMaxScaler()

# normalization
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.fit_transform(X_test)

# %%
#### ANN

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report
from sklearn.preprocessing import StandardScaler

# Assuming you have X_train_scaled, X_test_scaled, y_train, and y_test already defined

# Create an MLP (Artificial Neural Network) model
ANNmodel = MLPClassifier(random_state=42)
ANNmodel.fit(X_train_scaled, y_train)

# Make predictions on the test set
ANN_predictions = ANNmodel.predict(X_test_scaled)

# Calculate training accuracy
training_accuracy = ANNmodel.score(X_train_scaled, y_train)
print("The accuracy of the model on the training data is: {:.2f}%".format(training_accuracy * 100))
print()

# Display classification report
print("Classification Report:")
print(classification_report(y_test, ANN_predictions))
# Out:
# The accuracy of the model on the training data is: 72.83%
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            f       0.43      0.04      0.08       613
#            m       0.72      0.98      0.83      1544
#
#     accuracy                           0.71      2157
#    macro avg       0.57      0.51      0.45      2157
# weighted avg       0.64      0.71      0.62      2157

# %% [markdown]
# #### Random forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import numpy as np



# Initialize an empty list to store accuracies
accuracies = []

# Define a list of values for the number of estimators (trees)
n_estimators_list = list(range(1, 11))

# Loop through different number of estimators
for n_estimators in n_estimators_list:
    # Create a Random Forest model
    RFmodel = RandomForestClassifier(n_estimators=n_estimators, random_state=42)

    # Fit the model to the training data
    RFmodel.fit(X_train_scaled, y_train)

    # Make predictions on the test set
    predictions = RFmodel.predict(X_test_scaled)

    # Calculate accuracy and append to the list
    accuracy = accuracy_score(y_test, predictions)
    accuracies.append(accuracy)

# Plot the results
plt.plot(n_estimators_list, accuracies)
plt.xlabel("Number of Estimators (Trees)")
plt.ylabel("Test set Accuracy")
plt.title("Accuracy of Random Forest Model on Test Set")
plt.show()

# Convert the list to a NumPy array for easier analysis
l_np = np.asarray(accuracies)

# Find the best number of estimators for the best accuracy
best_n_estimators = n_estimators_list[l_np.argmax()]
print(f"Best number of estimators for the best accuracy is: {best_n_estimators}")
# Out:
# Best number of estimators for the best accuracy is: 5

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score


# Set the best number of estimators
best_n_estimators = 5

# Create a Random Forest model with the best number of estimators
RFmodel = RandomForestClassifier(n_estimators=5, random_state=42)

# Fit the model to the training data
RFmodel.fit(X_train_scaled, y_train)

# Calculate training accuracy
training_accuracy = RFmodel.score(X_train_scaled, y_train)
print("The accuracy of the model on training data is: {}%".format(round(training_accuracy, 2) * 100))
print()

# Make predictions on the test set
predictions = RFmodel.predict(X_test_scaled)

# Print classification report for the test set
print(classification_report(y_test, predictions))
# Out:
# The accuracy of the model on training data is: 74.0%
#
#               precision    recall  f1-score   support
#
#            f       0.47      0.06      0.10       613
#            m       0.72      0.97      0.83      1544
#
#     accuracy                           0.71      2157
#    macro avg       0.59      0.52      0.47      2157
# weighted avg       0.65      0.71      0.62      2157

# %% [markdown]
# #### Logistic Regression

# %%
logReg_model = LogisticRegression(multi_class= "multinomial")

logReg_model.fit(X_train_scaled, y_train)

training_accuracy = logReg_model.score(X_train_scaled, y_train)

print("The accuracy of model on training data is: {}%".format(round(training_accuracy, 2) *100))
print()

predictions = logReg_model.predict(X_test_scaled)

print(classification_report(y_test, predictions))
# Out:
# The accuracy of model on training data is: 73.0%
#
#               precision    recall  f1-score   support
#
#            f       0.33      0.00      0.00       613
#            m       0.72      1.00      0.83      1544
#
#     accuracy                           0.72      2157
#    macro avg       0.52      0.50      0.42      2157
# weighted avg       0.61      0.72      0.60      2157

# %% [markdown]
# #### Decision Tree

# %%
DTmodel = DecisionTreeClassifier()

DTmodel.fit(X_train_scaled, y_train)

training_accuracy = DTmodel.score(X_train_scaled, y_train)

print("The accuracy of model on training data is: {}%".format(round(training_accuracy, 2) *100))
print()

predictions = DTmodel.predict(X_test_scaled)

print(classification_report(y_test, predictions))

#print(DTmodel.get_depth())
# Out:
# The accuracy of model on training data is: 74.0%
#
#               precision    recall  f1-score   support
#
#            f       0.42      0.06      0.11       613
#            m       0.72      0.97      0.83      1544
#
#     accuracy                           0.71      2157
#    macro avg       0.57      0.51      0.47      2157
# weighted avg       0.64      0.71      0.62      2157

# %% [markdown]
# #### SVC

# %%
SVCmodel = SVC(kernel = 'linear', C = 1)

SVCmodel.fit(X_train_scaled, y_train)

training_accuracy = SVCmodel.score(X_train_scaled, y_train)

print("The accuracy of model on training data is: {}%".format(round(training_accuracy, 2) *100))
print()

predictions = SVCmodel.predict(X_test_scaled)

print(classification_report(y_test, predictions))
# Out:
# The accuracy of model on training data is: 73.0%
#
#               precision    recall  f1-score   support
#
#            f       0.25      0.00      0.00       613
#            m       0.72      1.00      0.83      1544
#
#     accuracy                           0.71      2157
#    macro avg       0.48      0.50      0.42      2157
# weighted avg       0.58      0.71      0.60      2157

# %% [markdown]
# This time the accuracy of all five models is approximately 71-74% which is very promising. We conclude that we can predict sex of the user with education level and income relatively well.

# %% [markdown]
# # Activity 7 - Model Comparison and Evaluation:

# %% [markdown]
# Task 1: Compare the performance of different models.
# • Task 2: Evaluate accuracy, precision, recall, and F1-score of each model.
# • Task 3: Identify strengths and weaknesses of each model.
# • Task 4: Summarize model comparison results.
# • Task 5: Provide recommendations based on model performance.

# %% [markdown]
# ### Overall, models are all comparaby weak when it comes to evaluating and analysing the data. Given the nature of features to use for prediction, the subjective variables make it hard for accurate predictions. Only when it comes to numerical features (e.g. income, height) for predicting sex, the models could work better.

# %% [markdown]
# #### Conclusions

# %% [markdown]
# - Most of the users are between 25 to 35 years old.
# - There are more male users than female users.
# - Males are generally taller than females.
# - (Activity 3) We cannot predict Zodiac signs using 'body_type', 'education', 'diet', 'orientation', 'pets', 'religion_cleaned', 'sex', 'job', 'smokes', 'drinks' and 'drugs' features.
# - (Activity 4) We cannot predict body type by using lifestyle information ('diet', 'smokes', 'drinks', 'drugs'), sex and age.
# - (Activity 5) We cannot predict the income of the user by making models based on their job, sex and education.
# - (Activity 6) We can build good models with high accuracy(71-74%) to predict sex of an user with education level and income.
# - However, an accurate model can be built to predict the gender of an user based on their height and body type. The accuracy is 85% with SVM, Logistic Regression, Decision Tree and KNN models.

# %% [markdown]
# #### Further Improvements

# %% [markdown]
# Further Improvements:
# The dataset, given its numerous categorical variables, is difficult to use for drawing strong correlations between its features. Hence, models made and predictions drawn are not strong. In the future, we can focus more on statistical or numerical features and draw correlations between them, or include less categorical features for analysis.
